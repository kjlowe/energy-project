# %% [markdown]
# # Get Data from Excel
#
# I am going to continue to use excel as the data entry user interface.

# %%
import pandas as pd

# Read data from Google Sheets
# url = f"https://docs.google.com/spreadsheets/d/1GuHkRddZm5Idxfa-IUlA-lXQFydduyau/gviz/tq?tqx=out:csv&sheet=Billing"
# df = pd.read_csv(url)

# Read data as excel file
# curl -L https://docs.google.com/spreadsheets/d/1GuHkRddZm5Idxfa-IUlA-lXQFydduyau/export?format=xlsx&sheet=Billing --output billing.xlsx

# read excel file billing.xlsx with the following instructions
# - first lin is blank ignore
# - 2, 3, 4, 5, 6 are are headers
df_excel_billing = pd.read_excel("billing.xlsx", header=[1, 2, 3, 4, 5])

# %% [markdown]
# # Create structure for storing & analyzing the data
#
# Choosing to do an object oriented class structure because will want to have lots of little nested functions to help me out.

# %%
from dataclasses import dataclass
from typing import List, Optional
from enum import Enum
import datetime
from typing import List
import calendar

class NEM2A_MeterType(Enum):
    GenerationMeter = 1
    BenefitMeter = 2

class WhereFrom(Enum):
    PDF_BILL = 1
    PDF_DETAIL_OF_BILL = 2
    CALCULATED = 3
    FIXED_VALUE = 4
    NOT_PROVIDED = 5


# Stores information about where something is found in the PG&E billing system.
# It could be for many types of information, such as a date, a kWh value, or a cost.
@dataclass
class WhereFound:
    where_from: Optional[WhereFrom] = None    # tells the person where to find this on the bill
    where_on_pdf: Optional[str] = None        # tells the person where to find this on the bill
    kevins_number_code: Optional[int] = None  # a number that Kevin can use to identify this metric by looking at the november 2024 sample bill

# Represents a date and where to find that date in the PG&E billing system.
class EnergyDate:
    value: Optional[datetime.date] = None
    where_found: List[WhereFound] = None

    def __init__(self, value: Optional[datetime.date] = None, where_found: Optional[List[WhereFound]] = None):
        self.value = value
        self.where_found = where_found if where_found is not None else []

# Represents an energy or cost metric with value(s), unit, and where it was found.
class EnergyMetric:

    # Sometimes each metric comes from multiple values summed up.
    # This can happen when the rates change half way through the month (due to summer/winter trasitions or rake hikes)
    subcomponent_values: List[float] = None

    # The unit of the metric, such as kWh or $
    unit: Optional[str] = None

    # Where this metric was found in the PG&E billing system.
    where_found: List[WhereFound] = None

    def __init__(self, unit: Optional[str] = None):
        self.subcomponent_values = []
        self.unit = unit
        self.where_found = []

    # function to get the total of the subcomponent values
    def get_total(self) -> Optional[float]:
        if self.subcomponent_values:
            return sum(self.subcomponent_values)
        else:
            return 0

# Some energy metrics are time-of-use (TOU) based, meaning they have different values for peak and off-peak times.
class EnergyMetricTOU:
    peak: EnergyMetric
    off_peak: EnergyMetric
    total: EnergyMetric

    # constructor which initializes the value to None, unit to None, and where_found to an empty list
    def __init__(self, unit: Optional[str]):
        self.peak = EnergyMetric(unit)
        self.off_peak = EnergyMetric(unit)
        self.total = EnergyMetric(unit)

# Represents a monthly bill for a single meter within the NEM2A system.
class MeterBillingMonth:

    # The type of meter, either GenerationMeter or BenefitMeter
    nem2a_meter_type                : NEM2A_MeterType

    # key dates
    billing_date                    : EnergyDate
    service_end_date                : EnergyDate

    # Meter values (kWh) are always mapped to time of used.
    energy_export_meter_channel_2   : EnergyMetricTOU
    energy_import_meter_channel_1   : EnergyMetricTOU
    allocated_export_energy_credits : EnergyMetricTOU
    net_energy_usage_after_credits  : EnergyMetricTOU

    # PCE values
    pce_energy_cost                 : EnergyMetricTOU # cost is always TOU based
    pce_net_generation_bonus        : EnergyMetric
    pce_energy_commission_surcharge : EnergyMetric
    pce_total_energy_charges        : EnergyMetric
    pce_nem_credit                  : EnergyMetric
    pce_generation_charges_due_cash : EnergyMetric

    # PG&E
    pge_res_energy_charges          : EnergyMetric
    pge_baseline_credit             : EnergyMetric
    pge_da_cca_charges              : EnergyMetric
    pge_total_energy_charges        : EnergyMetric
    pge_nem_billing                 : EnergyMetric
    pge_minimum_delivery_charge     : EnergyMetric
    pge_nem_true_up_adjustment      : EnergyMetric
    pge_electric_delivery_charges   : EnergyMetric

    # Totals
    california_climate_credit       : EnergyMetric
    total_bill_in_mail              : EnergyMetric

    # Store the meter type as an instance variable
    def __init__(self, nem2a_meter_type: NEM2A_MeterType):

        # Store the meter type
        self.nem2a_meter_type = nem2a_meter_type

        # key dates are the same for both types of meters
        self.billing_date        = EnergyDate(where_found=[WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Header", kevins_number_code=43) ])
        self.service_end_date    = EnergyDate(where_found=[WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges"),
                                                           WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 1", kevins_number_code=44)])

        # Metering units are always kWh
        self.energy_export_meter_channel_2   = EnergyMetricTOU("kWh")
        self.energy_import_meter_channel_1   = EnergyMetricTOU("kWh")
        self.allocated_export_energy_credits = EnergyMetricTOU("kWh")
        self.net_energy_usage_after_credits  = EnergyMetricTOU("kWh")

        # PCE values always in $
        self.pce_energy_cost                 = EnergyMetricTOU("$")
        self.pce_net_generation_bonus        = EnergyMetric(unit = "$")
        self.pce_energy_commission_surcharge = EnergyMetric(unit = "$")
        self.pce_total_energy_charges        = EnergyMetric(unit = "$")
        self.pce_nem_credit                  = EnergyMetric(unit = "$")
        self.pce_generation_charges_due_cash = EnergyMetric(unit = "$")

        # PG&E values always in $
        self.pge_res_energy_charges          = EnergyMetric(unit = "$")
        self.pge_baseline_credit             = EnergyMetric(unit = "$")
        self.pge_da_cca_charges              = EnergyMetric(unit = "$")
        self.pge_total_energy_charges        = EnergyMetric(unit = "$")
        self.pge_nem_billing                 = EnergyMetric(unit = "$")
        self.pge_minimum_delivery_charge     = EnergyMetric(unit = "$")
        self.pge_nem_true_up_adjustment      = EnergyMetric(unit = "$")
        self.pge_electric_delivery_charges   = EnergyMetric(unit = "$")

        # Totals values always in $
        self.california_climate_credit       = EnergyMetric(unit = "$")
        self.total_bill_in_mail              = EnergyMetric(unit = "$")

        # METER CHANNEL 2: energy exported
        if nem2a_meter_type == NEM2A_MeterType.GenerationMeter:
            self.energy_export_meter_channel_2.off_peak.where_found.append(WhereFound(where_from=WhereFrom.CALCULATED))
            self.energy_export_meter_channel_2.peak.where_found.append(WhereFound(where_from=WhereFrom.CALCULATED))
            self.energy_export_meter_channel_2.total.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 3", kevins_number_code = 15))
        elif nem2a_meter_type == NEM2A_MeterType.BenefitMeter:
            # Never any export on a benefit meter
            self.energy_export_meter_channel_2.off_peak.where_found.append(WhereFound(where_from=WhereFrom.FIXED_VALUE))
            self.energy_export_meter_channel_2.off_peak.subcomponent_values = [0]
            self.energy_export_meter_channel_2.peak.where_found.append(WhereFound(where_from=WhereFrom.FIXED_VALUE))
            self.energy_export_meter_channel_2.peak.subcomponent_values = [0]
            self.energy_export_meter_channel_2.total.where_found.append(WhereFound(where_from=WhereFrom.FIXED_VALUE))
            self.energy_export_meter_channel_2.total.subcomponent_values = [0]

        # METER CHANNEL 1: energy imported
        if nem2a_meter_type == NEM2A_MeterType.GenerationMeter:
            self.energy_import_meter_channel_1.off_peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 5", kevins_number_code = 3))
            self.energy_import_meter_channel_1.peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 5", kevins_number_code = 4))
            self.energy_import_meter_channel_1.total.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 3", kevins_number_code = 10))
        elif nem2a_meter_type == NEM2A_MeterType.BenefitMeter:
            self.energy_import_meter_channel_1.off_peak.where_found.append(WhereFound(where_from=WhereFrom.CALCULATED))
            self.energy_import_meter_channel_1.peak.where_found.append(WhereFound(where_from=WhereFrom.CALCULATED))
            self.energy_import_meter_channel_1.total.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 3", kevins_number_code = 9))


        # ALLOCATED CREDITS
        if nem2a_meter_type == NEM2A_MeterType.GenerationMeter:
            self.allocated_export_energy_credits.off_peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 5", kevins_number_code = 5))
            self.allocated_export_energy_credits.peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 5", kevins_number_code = 6))
            self.allocated_export_energy_credits.total.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 3", kevins_number_code = 14))
        elif nem2a_meter_type == NEM2A_MeterType.BenefitMeter:
            self.allocated_export_energy_credits.off_peak.where_found.append(WhereFound(where_from=WhereFrom.CALCULATED))
            self.allocated_export_energy_credits.peak.where_found.append(WhereFound(where_from=WhereFrom.CALCULATED))
            self.allocated_export_energy_credits.total.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 3", kevins_number_code = 13))


        # net energy usage after credits is calculated
        if nem2a_meter_type == NEM2A_MeterType.GenerationMeter:
            # off peak found in 2 places
            self.net_energy_usage_after_credits.off_peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 23))
            self.net_energy_usage_after_credits.off_peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 6"))
            # peak found in 2 places
            self.net_energy_usage_after_credits.peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 22))
            self.net_energy_usage_after_credits.peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 6"))
            # total found in 1 place
            self.net_energy_usage_after_credits.total.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 6", kevins_number_code = 7))
        elif nem2a_meter_type == NEM2A_MeterType.BenefitMeter:
            self.net_energy_usage_after_credits.off_peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 21))
            self.net_energy_usage_after_credits.peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 20))
            self.net_energy_usage_after_credits.total.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 6", kevins_number_code = 8))

        # pce energy cost
        if nem2a_meter_type == NEM2A_MeterType.GenerationMeter:
            self.pce_energy_cost.off_peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 33))
            self.pce_energy_cost.peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 34))
            self.pce_energy_cost.total.where_found.append(WhereFound(where_from=WhereFrom.CALCULATED))
        elif nem2a_meter_type == NEM2A_MeterType.BenefitMeter:
            self.pce_energy_cost.off_peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 24))
            self.pce_energy_cost.peak.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 25))
            self.pce_energy_cost.total.where_found.append(WhereFound(where_from=WhereFrom.CALCULATED))

        # other pce costs
        if nem2a_meter_type == NEM2A_MeterType.GenerationMeter:
            self.pce_net_generation_bonus.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 37))
        elif nem2a_meter_type == NEM2A_MeterType.BenefitMeter:
            self.pce_net_generation_bonus.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 26))

        if nem2a_meter_type == NEM2A_MeterType.GenerationMeter:
            self.pce_energy_commission_surcharge.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 35))
        elif nem2a_meter_type == NEM2A_MeterType.BenefitMeter:
            self.pce_energy_commission_surcharge.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 27))

        if nem2a_meter_type == NEM2A_MeterType.GenerationMeter:
            self.pce_total_energy_charges.where_found.append(WhereFound(where_from=WhereFrom.CALCULATED))
        elif nem2a_meter_type == NEM2A_MeterType.BenefitMeter:
            self.pce_total_energy_charges.where_found.append(WhereFound(where_from=WhereFrom.CALCULATED))

        if nem2a_meter_type == NEM2A_MeterType.GenerationMeter:
            self.pce_nem_credit.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 36))
        elif nem2a_meter_type == NEM2A_MeterType.BenefitMeter:
            self.pce_nem_credit.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 28))

        if nem2a_meter_type == NEM2A_MeterType.GenerationMeter:
            self.pce_generation_charges_due_cash.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 80))
        elif nem2a_meter_type == NEM2A_MeterType.BenefitMeter:
            self.pce_generation_charges_due_cash.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Generation Charges", kevins_number_code = 29))

        # pg&e costs that are only found on generation meter side.
        # TODO: figure out how to calcualte these for benefit meter after true up.
        if nem2a_meter_type == NEM2A_MeterType.GenerationMeter:
            self.pge_res_energy_charges.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 4", kevins_number_code = 31))
            self.pge_baseline_credit.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 4", kevins_number_code = 32))
            self.pge_da_cca_charges.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 4", kevins_number_code = 38))
            self.pge_total_energy_charges.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 4", kevins_number_code = 39))
            self.pge_nem_billing.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 4", kevins_number_code = 40))
            self.pge_minimum_delivery_charge.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 4", kevins_number_code = 41))
            self.pge_nem_true_up_adjustment.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 1 - True Up Only", kevins_number_code = 80))
        elif nem2a_meter_type == NEM2A_MeterType.BenefitMeter:
            self.pge_res_energy_charges.where_found.append(WhereFound(where_from=WhereFrom.NOT_PROVIDED))
            self.pge_baseline_credit.where_found.append(WhereFound(where_from=WhereFrom.NOT_PROVIDED))
            self.pge_da_cca_charges.where_found.append(WhereFound(where_from=WhereFrom.NOT_PROVIDED))
            self.pge_total_energy_charges.where_found.append(WhereFound(where_from=WhereFrom.NOT_PROVIDED))
            self.pge_nem_billing.where_found.append(WhereFound(where_from=WhereFrom.NOT_PROVIDED))
            self.pge_minimum_delivery_charge.where_found.append(WhereFound(where_from=WhereFrom.NOT_PROVIDED))
            self.pge_nem_true_up_adjustment.where_found.append(WhereFound(where_from=WhereFrom.NOT_PROVIDED))

        if nem2a_meter_type == NEM2A_MeterType.GenerationMeter:
            self.pge_electric_delivery_charges.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Electric Delivery Charges", kevins_number_code = 30))
            self.pge_electric_delivery_charges.where_found.append(WhereFound(where_from=WhereFrom.PDF_DETAIL_OF_BILL, where_on_pdf="Page 4"))
        elif nem2a_meter_type == NEM2A_MeterType.BenefitMeter:
            self.pge_electric_delivery_charges.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Electric Delivery Charges", kevins_number_code = 42))

        if nem2a_meter_type == NEM2A_MeterType.GenerationMeter:
            self.california_climate_credit.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Electric Delivery Charges", kevins_number_code = 45))
        elif nem2a_meter_type == NEM2A_MeterType.BenefitMeter:
            self.california_climate_credit.where_found.append(WhereFound(where_from=WhereFrom.PDF_BILL, where_on_pdf="Electric Delivery Charges", kevins_number_code = 46))

        # total bill is calcualted
        self.total_bill_in_mail.where_found.append(WhereFound(where_from=WhereFrom.CALCULATED))

    # function to get the total energy_export_meter_channel_2
    def get_total_energy_export(self):
        """
        Returns the total energy exported in kWh.
        If the meter type is GenerationMeter, it returns the total from channel 2.
        If the meter type is BenefitMeter, it returns 0.
        """

        if self.energy_export_meter_channel_2.total.subcomponent_values:
            return sum(self.energy_export_meter_channel_2.total.subcomponent_values)
        else:
            return 0

    # calculate calculated values for the billing month
    def calculate_values(self):

        self.pce_energy_cost.total.subcomponent_values.append(
            self.pce_energy_cost.off_peak.get_total() +
            self.pce_energy_cost.peak.get_total()
        )        

        self.pce_total_energy_charges.subcomponent_values.append(
            self.pce_energy_cost.total.get_total() +
            self.pce_net_generation_bonus.get_total() +
            self.pce_energy_commission_surcharge.get_total()
        )

        self.total_bill_in_mail.subcomponent_values.append(
            self.pce_generation_charges_due_cash.get_total() +
            self.pge_electric_delivery_charges.get_total() +
            self.california_climate_credit.get_total()
        )


# Represents a monthly bill for a single meter within the NEM2A system.
class NEM2AAggregationBillingMonth:

    year        : int
    month       : int
    month_label : tuple  # (month_name, year) e.g., ("January", 2024)

    main    : MeterBillingMonth
    adu     : MeterBillingMonth

    def __init__(self, year, month):

        # Store the calendar year and month for this billing month
        # year: e.g., 2024, month: 1=January, 12=December
        if year is not None and month is not None:
            self.year = year
            self.month = month
            self.month_label = (calendar.month_name[month], year)
        else:
            # raise exception if year or month is None
            raise ValueError("Year and month must be provided for MeterBillingMonth initialization.")

        self.main = MeterBillingMonth(nem2a_meter_type=NEM2A_MeterType.GenerationMeter)
        self.adu = MeterBillingMonth(nem2a_meter_type=NEM2A_MeterType.BenefitMeter)

    # function to print the billing month and year on a single line, both as numeric and tuple
    def print_month(self):
        print(f"{self.month_label}")

    # function to return the month as a tuple (year, month numeric)
    def get_month_as_tuple(self):
        return (self.year, self.month)

    # function to get the total energy exported to the grid for this month
    def get_total_energy_export(self):
        return self.main.get_total_energy_export()

    # calculate calculated values for the billing month
    def calculate_values(self):
        self.main.calculate_values()
        self.adu.calculate_values()

        # Total amount of energy export from the NEM2A system 
        total_kwh_exported = self.main.energy_export_meter_channel_2.total.get_total()

        # only do allocation if there was energy exported for this billing month.
        if total_kwh_exported < 0:

            main_allocation_percentage = (self.main.allocated_export_energy_credits.total.get_total() 
                                          / total_kwh_exported)
            
            # MAIN UNIT: calculate the total meter export energy on channel 2
            self.main.energy_export_meter_channel_2.peak.subcomponent_values = [self.main.allocated_export_energy_credits.peak.get_total() 
                                                                                / main_allocation_percentage]

            self.main.energy_export_meter_channel_2.off_peak.subcomponent_values = [self.main.allocated_export_energy_credits.off_peak.get_total() 
                                                                                    / main_allocation_percentage]

            # ADU UNIT: calculate the peak and off-peak allocated export credits based on the leftovers
            adu_allocation_percentage = (self.adu.allocated_export_energy_credits.total.get_total() 
                                         / total_kwh_exported)
            
            self.adu.allocated_export_energy_credits.peak.subcomponent_values = [self.main.energy_export_meter_channel_2.peak.get_total() - 
                                                                                 self.main.allocated_export_energy_credits.peak.get_total()]
            
            self.adu.allocated_export_energy_credits.off_peak.subcomponent_values = [self.main.energy_export_meter_channel_2.off_peak.get_total() - 
                                                                                     self.main.allocated_export_energy_credits.off_peak.get_total()]
            
        else:
            # if no energy exported, set allocated credits to zero
            self.main.energy_export_meter_channel_2.peak.subcomponent_values = [0]
            self.main.energy_export_meter_channel_2.off_peak.subcomponent_values = [0]
            self.adu.allocated_export_energy_credits.peak.subcomponent_values = [0]
            self.adu.allocated_export_energy_credits.off_peak.subcomponent_values = [0]


        self.adu.energy_import_meter_channel_1.peak.subcomponent_values = [self.adu.net_energy_usage_after_credits.peak.get_total() -
                                                                            self.adu.allocated_export_energy_credits.peak.get_total()]
        
        self.adu.energy_import_meter_channel_1.off_peak.subcomponent_values = [self.adu.net_energy_usage_after_credits.off_peak.get_total() -
                                                                                self.adu.allocated_export_energy_credits.off_peak.get_total()]

# Represents a billing year, which consists of multiple billing months.
class BillingYear:

    start_month : int
    start_year  : int
    num_months  : int
    months      : List[tuple]  # List of tuples (month_name, year)
    billing_months: List[NEM2AAggregationBillingMonth]

    def __init__(self, start_month: int, start_year: int, num_months: int = 12):
        """
        start_month: 1=January, 12=December
        start_year: e.g., 2024
        num_months: number of months in the billing year (default 12)
        """
        self.start_month = start_month
        self.start_year = start_year
        self.num_months = num_months
        self.months = self._generate_months()

        # Create a dictionary where the key is (year, month) and the value is NEM2AAggregationBillingMonth
        self.billing_months: dict = {
            (self.months[i][0], self.months[i][1]): NEM2AAggregationBillingMonth(year=self.months[i][0], month=self.months[i][1])
            for i in range(self.num_months)
        }

    def _generate_months(self):
        months = []
        year = self.start_year
        month = self.start_month
        for _ in range(self.num_months):
            months.append((year, month))
            month += 1
            if month > 12:
                month = 1
                year += 1
        return months

    # function to print out all the billing months in the year
    def print_months(self):
        # self.billing_months is now a dict with keys as (year, month) tuples and values as NEM2AAggregationBillingMonth
        for month_obj in self.billing_months.values():
            month_obj.print_month()

    # function to get all billing months as an array of tuples (year, month numeric)
    def get_months_as_tuples(self):
        # self.billing_months is now a dict with keys as (year, month) tuples and values as NEM2AAggregationBillingMonth
        return list(self.billing_months.keys())

    # function to get the start year of the billing year
    def get_start_year(self):
        return self.start_year

    # get total energy exported to the grid for the entire year
    def get_total_energy_exported(self):
        total_exported = 0
        for month_obj in self.billing_months.values():
            total_exported += month_obj.get_total_energy_export()
        return total_exported

    # calculate all the values for the billing year
    def calculate_values(self):
        for month_obj in self.billing_months.values():
            month_obj.calculate_values()

# %% [markdown]
# # Map Excel data into the OOP structure
#
# Using the (#) code system to do this.
# This is a work in progress as I'm trying to do this in a way that is not super fragile.

# %% [markdown]
# ### Support functions to get the path to EnergyMetrics/Dates with a PDF where found location

# %%
from typing import Any

# Looks through the energy month object to find all values and their location in the PG&E billing system
# The purpose of getting this into an array is to make it easy to map the excel data into the object structure
def serialize_wherefound(obj: Any, path: str = "", visited=None):
    if visited is None:
        visited = set()
    results = []

    # Avoid infinite recursion by tracking visited objects
    obj_id = id(obj)
    if obj_id in visited:
        return results
    visited.add(obj_id)

    if isinstance(obj, WhereFound):
        # Serialize WhereFound as a dict
        results.append({
            "path": path,
            "where_from": obj.where_from.name if obj.where_from else None,
            "where_on_pdf": obj.where_on_pdf,
            "kevins_number_code": obj.kevins_number_code
        })
    elif isinstance(obj, list):
        for idx, item in enumerate(obj):
            results.extend(serialize_wherefound(item, f"{path}[{idx}]", visited))

    elif hasattr(obj, "__dict__"):
        for attr, value in obj.__dict__.items():
            results.extend(serialize_wherefound(value, f"{path}.{attr}" if path else attr, visited))

    return results

# For the (#) code location in the PG&E PDF bill system mapped to the path of to value in the OOP data structure.
def get_object_path_by_numbercode(object: Any) -> dict:
    """
    Given a NEM2AAggregationBillingMonth object, serialize it and return a dictionary
    mapping kevins_number_code to a LIST of path info dictionaries (since some codes
    appear in multiple locations).
    """
    def find_object_by_path(obj, path_str):
        """
        Given an object and a dot-separated path (with optional [index]), return the referenced object.
        """
        parts = path_str.split('.')
        current = obj
        for part in parts:
            if '[' in part and ']' in part:
                attr, idx = part[:-1].split('[')
                current = getattr(current, attr)[int(idx)]
            else:
                current = getattr(current, part)
        return current

    # get a list of where founds in the data structure
    serialized = serialize_wherefound(object)

    object_path_by_numbercode = {}

    # Look through the wherefounds
    for item in serialized:

        # Only consider items that have a kevins_number_code and are from PDF_BILL or PDF_DETAIL_OF_BILL
        if item["where_from"] in [WhereFrom.PDF_BILL.name, WhereFrom.PDF_DETAIL_OF_BILL.name]:
            if item["kevins_number_code"] is not None:

                # The path is to the WhereFound object, so get the parent EnergyDate/EnergyMetric
                path_parts = item["path"].split('.')
                # Remove the last part (should be 'where_found[index]')
                parent_path = '.'.join(path_parts[:-1])
                parent_obj = find_object_by_path(object, parent_path)
                # Add the parent_obj reference to the item
                item_with_ref = dict(item)
                item_with_ref["ref_obj"] = parent_obj
                
                # Store as a list of items for each number code
                code = item["kevins_number_code"]
                if code not in object_path_by_numbercode:
                    object_path_by_numbercode[code] = []
                object_path_by_numbercode[code].append(item_with_ref)

    return object_path_by_numbercode


# Write a test function to verify the serialization works as expected
def test_serialize_wherefound():

    # Create a sample billing month object
    billingYear = BillingYear(start_month=5, start_year=2024)
    billingYear.billing_months[(2025, 4)].main.energy_export_meter_channel_2.total.subcomponent_values = [100]

    # Serialize it
    object_path_by_numbercode = get_object_path_by_numbercode(billingYear.billing_months[(2025, 4)])

    # Check that the (#) code 15 points to the correct path and has the right value
    # Now it returns a list, so we take the first element
    assert object_path_by_numbercode[15][0]["ref_obj"].subcomponent_values == [100]

    # check that it works in the reverse direction
    object_path_by_numbercode[15][0]["ref_obj"].subcomponent_values = [200]

    # Verify the change is reflected in the original object
    assert billingYear.billing_months[(2025, 4)].main.energy_export_meter_channel_2.total.subcomponent_values == [200]

# Run the test
test_serialize_wherefound()

# %% [markdown]
# ### Support functions to map the Excel df to the OOP data structure

# %%
import pandas as pd
import re
from typing import Any


# Find the (#) codes by Excel dataframe column
def extract_headers_by_number_code(df):
    """
    Given a pandas DataFrame with multi-level columns, extract a dictionary mapping
    (#) number codes to their column tuples.

    Args:
        df: pandas DataFrame with multi-level columns.

    Returns:
        headers_by_number_code: dict mapping number code (int) -> column tuple.
    """
    headers_by_number_code = {}
    for col in df.columns:
        # look through the col for an integer number inside of parenthesis like (#)
        match = re.search(r"\((\d+)\)", str(col))
        if match:
            # Store as a key-value pair: number -> column name (tuple)
            headers_by_number_code[int(match.group(1))] = col
    return headers_by_number_code

# Groups excel rows by month
def group_rows_by_billing_month(excel_dates, billing_year):
    """
    Groups row indices by (year, month) tuple for the given billing year.

    Args:
        excel_dates: pandas Series of dates (can include NaT).
        billing_year: BillingYear object.

    Returns:
        month_groups: dict mapping (year, month) -> list of row indices.
    """
    # Get all months as (year, month) tuples from the BillingYear object
    months_as_tuples = billing_year.get_months_as_tuples()

    # Initialize a dictionary to hold row indices for each month
    month_groups = {month_tuple: [] for month_tuple in months_as_tuples}
    current_month = ()

    # Iterate through the excel_dates Series to assign each row to a billing month
    for i, date in enumerate(excel_dates):

        # If the date is a valid Timestamp or datetime.date and not NaT
        if isinstance(date, (pd.Timestamp, datetime.date)) and not pd.isna(date):
            month_tuple = (date.year, date.month)

            if month_tuple not in month_groups:
                # Optionally log or warn here if the month is not in the billing year
                continue
            current_month = month_tuple
            month_groups[current_month].append(i)

        else:
            # If the date is NaT, assign the row to the most recent month found
            if current_month != ():
                month_groups[current_month].append(i)
    return month_groups

# helper function to make the data frame
def extract_values_by_month_group(rows_assigned_to_each_month, headers_by_number_code, df_excel_billing):
    """
    Given rows_assigned_to_each_month (dict of (year, month) -> list of row indices), headers_by_number_code (dict),
    and the excel dataframe, return a DataFrame with all number codes as columns, indexed by (Month, Excel Row #).
    """

    data = []
    number_codes = list(headers_by_number_code.keys())
    for month in rows_assigned_to_each_month:
        month_rows = rows_assigned_to_each_month[month]
        for row in month_rows:
            row_data = {
                "Month": month,
                "Excel Row #": row
            }
            for code in number_codes:
                col = headers_by_number_code[code]
                value = df_excel_billing.iloc[row][col] if col in df_excel_billing.columns else None
                row_data[code] = value
            data.append(row_data)
    extracted_values_df = pd.DataFrame(data)
    extracted_values_df.set_index(["Month", "Excel Row #"], inplace=True)
    return extracted_values_df

# generates a dataframe based on excel, billing year month and (#) codes
def generate_dataframe_for_billing_year_from_excel(billing_year, df_excel_billing, headers_by_number_code):
    """
    Generates a DataFrame for the given billing year using the provided Excel billing data.
    Args:
        billing_year: BillingYear object.
        df_excel_billing: DataFrame containing the Excel billing data.
        headers_by_number_code: Dictionary mapping number codes to column names.
    Returns:
        DataFrame with all number codes as columns, indexed by (Month, Excel Row #).
    """

    # EXCEL FILE: Get all rows in the Service End dates column
    service_end_dates = df_excel_billing[headers_by_number_code[44]]

    # figure out which rows in the excel file belong to which month
    rows_assigned_to_each_month = group_rows_by_billing_month(service_end_dates, billing_year)

    # Extrack all values for each month and return a DataFrame
    extracted_values_df = extract_values_by_month_group(rows_assigned_to_each_month, headers_by_number_code, df_excel_billing)

    return extracted_values_df

# %% [markdown]
# ### Copy the Excel data into the OOP data strcture

# %%
# EXCEL: Extract headers by number code from the excel billing DataFrame
headers_by_number_code = extract_headers_by_number_code(df_excel_billing)

# OOP STRUCTURE: generate a DataFrame based on the 2024 billing year period using the excel data
billing_year_2024 = BillingYear(start_month=5, start_year=2024)
billing_year_2024_df = generate_dataframe_for_billing_year_from_excel(billing_year_2024, df_excel_billing, headers_by_number_code)

# Print the DataFrame for the billing year 2024
billing_year_2024_df

# Loop through the DataFrame and map values to the OOP structure
count_valid_value_added = 0
count_invalid_values_not_added = 0
previous_month_tuple = ()

# May an array to hold refernces to any EnergyMetrics that have more than one value added to them in an array
energy_metrics_with_multiple_values = []

# function to check if an ENergyMetric is already added to the array
def is_energy_metric_in_list(energy_metric, metric_list):
    for metric in metric_list:
        if metric is energy_metric:
            return True
    return False

for (month_tuple, excel_row), row in billing_year_2024_df.iterrows():

    # Each month will have one object per number code
    object_path_by_numbercode = get_object_path_by_numbercode(billing_year_2024.billing_months[month_tuple])

    # There is only one set of dates per month.
    if month_tuple != previous_month_tuple:
        dates_filled_in = False

    # Loop through the number codes in the row
    for number_code in headers_by_number_code.keys():

        # get the path for the number code
        if number_code not in object_path_by_numbercode:
            continue

        # Now path_info_list is a list of all locations with this number code
        path_info_list = object_path_by_numbercode[number_code]
        
        # Process each location (usually just one, but can be multiple)
        for path_info in path_info_list:

            if type(path_info['ref_obj']) == EnergyDate:

                # if it's a valid date store it.
                if pd.notna(row[number_code]) and isinstance(row[number_code], (pd.Timestamp, datetime.date)):
                    path_info['ref_obj'].value = pd.to_datetime(row[number_code]).date()
                    count_valid_value_added += 1

                elif not dates_filled_in:
                    # Throw exception if the value is NaN or not a valid date
                    print(f"Processing month: {month_tuple}. Excel Row: {excel_row}: Invalid DATE value for {path_info['path']}: {row[number_code]}")
                    count_invalid_values_not_added += 1

            elif type(path_info['ref_obj']) == EnergyMetric:

                # check if the value is not NaN and is a valid number
                if pd.notna(row[number_code]):

                    if isinstance(row[number_code], (int, float)):
                        # add the value to the subcomponent values
                        path_info['ref_obj'].subcomponent_values.append(row[number_code])
                        count_valid_value_added += 1

                        number_of_subcomponents = len(path_info['ref_obj'].subcomponent_values)
                        # If there is more than one value added to this EnergyMetric, log it
                        if number_of_subcomponents > 1:
                            if not is_energy_metric_in_list(path_info['ref_obj'], energy_metrics_with_multiple_values):
                                energy_metrics_with_multiple_values.append(path_info['ref_obj'])

                    else:
                        # Throw exception if the value is not valid number
                        print(f"Processing month: {month_tuple}. Excel Row: {excel_row}: Invalid NUMERIC value for {path_info['kevins_number_code']}: {row[number_code]}")
                        count_invalid_values_not_added += 1

    # Once we've gone through all number codes for a month
    dates_filled_in = True
    previous_month_tuple = month_tuple

# loop through the energy metrics with multiple value and get remove the first value
# this is because in the excel file the first value is the total and if there are multiple values
# the subsequent values are the actual subcomponents that add up to the total.
for energy_metric in energy_metrics_with_multiple_values:
    first_value = energy_metric.subcomponent_values[0]
    energy_metric.subcomponent_values = energy_metric.subcomponent_values[1:]

# calculate all the values for the billing year
billing_year_2024.calculate_values()

print(f"Total valid values added: {count_valid_value_added}")
print(f"Total invalid values not added: {count_invalid_values_not_added}")
# Out:
# Total valid values added: 630
# Total invalid values not added: 0

# %% [markdown]
# ### Some tests to ensure the import worked correctly

# %%
# get the total energy exported for the main meter in the billing year
print(f"Value for May 2024 bill channel 1 import total (10) is: {billing_year_2024.billing_months[(2024, 5)].main.energy_import_meter_channel_1.total.subcomponent_values}")

print(f"Value for March 2025 bill channel 1 import peak (4) is: {billing_year_2024.billing_months[(2025, 3)].main.energy_import_meter_channel_1.peak.subcomponent_values}")

print(f"Total exported energy for the year 2024: {billing_year_2024.get_total_energy_exported()} kWh")
# Out:
# Value for May 2024 bill channel 1 import total (10) is: [382.0]
# Value for March 2025 bill channel 1 import peak (4) is: [204.0, 82.0]
# Total exported energy for the year 2024: -12394.0 kWh

# %% [markdown]
# # Print out OOP data structure
#
# Print out the OOP data structure in a format so that it can be injested into the sqlite database.

# %%
import json

def serialize_billing_year(billing_year):
    """
    Serialize the entire BillingYear object to a JSON-compatible dictionary.
    """
    
    def serialize_energy_date(ed):
        return {
            "value": ed.value.isoformat() if ed.value else None
        }
    
    def serialize_energy_metric(em):
        return {
            "subcomponent_values": em.subcomponent_values
        }
    
    def serialize_energy_metric_tou(emt):
        return {
            "peak": serialize_energy_metric(emt.peak),
            "off_peak": serialize_energy_metric(emt.off_peak),
            "total": serialize_energy_metric(emt.total)
        }
    
    def serialize_meter_billing_month(mbm):
        return {
            "nem2a_meter_type": mbm.nem2a_meter_type.name,
            "billing_date": serialize_energy_date(mbm.billing_date),
            "service_end_date": serialize_energy_date(mbm.service_end_date),
            "energy_export_meter_channel_2": serialize_energy_metric_tou(mbm.energy_export_meter_channel_2),
            "energy_import_meter_channel_1": serialize_energy_metric_tou(mbm.energy_import_meter_channel_1),
            "allocated_export_energy_credits": serialize_energy_metric_tou(mbm.allocated_export_energy_credits),
            "net_energy_usage_after_credits": serialize_energy_metric_tou(mbm.net_energy_usage_after_credits),
            "pce_energy_cost": serialize_energy_metric_tou(mbm.pce_energy_cost),
            "pce_net_generation_bonus": serialize_energy_metric(mbm.pce_net_generation_bonus),
            "pce_energy_commission_surcharge": serialize_energy_metric(mbm.pce_energy_commission_surcharge),
            "pce_total_energy_charges": serialize_energy_metric(mbm.pce_total_energy_charges),
            "pce_nem_credit": serialize_energy_metric(mbm.pce_nem_credit),
            "pce_generation_charges_due_cash": serialize_energy_metric(mbm.pce_generation_charges_due_cash),
            "pge_res_energy_charges": serialize_energy_metric(mbm.pge_res_energy_charges),
            "pge_baseline_credit": serialize_energy_metric(mbm.pge_baseline_credit),
            "pge_da_cca_charges": serialize_energy_metric(mbm.pge_da_cca_charges),
            "pge_total_energy_charges": serialize_energy_metric(mbm.pge_total_energy_charges),
            "pge_nem_billing": serialize_energy_metric(mbm.pge_nem_billing),
            "pge_minimum_delivery_charge": serialize_energy_metric(mbm.pge_minimum_delivery_charge),
            "pge_nem_true_up_adjustment": serialize_energy_metric(mbm.pge_nem_true_up_adjustment),
            "pge_electric_delivery_charges": serialize_energy_metric(mbm.pge_electric_delivery_charges),
            "california_climate_credit": serialize_energy_metric(mbm.california_climate_credit),
            "total_bill_in_mail": serialize_energy_metric(mbm.total_bill_in_mail)
        }
    
    def serialize_nem2a_aggregation_billing_month(nem2a_month):
        return {
            "year": nem2a_month.year,
            "month": nem2a_month.month,
            "month_label": {
                "month_name": nem2a_month.month_label[0],
                "year": nem2a_month.month_label[1]
            },
            "main": serialize_meter_billing_month(nem2a_month.main),
            "adu": serialize_meter_billing_month(nem2a_month.adu)
        }
    
    # Build the complete JSON structure
    billing_months_data = [
        serialize_nem2a_aggregation_billing_month(billing_year.billing_months[month_tuple])
        for month_tuple in billing_year.get_months_as_tuples()
    ]
    
    result = {
        "start_month": billing_year.start_month,
        "start_year": billing_year.start_year,
        "num_months": billing_year.num_months,
        "billing_months": billing_months_data
    }
    
    return result

# Serialize and print the entire billing_year_2024 object
complete_json = serialize_billing_year(billing_year_2024)
print(json.dumps(complete_json, indent=2))

# Optionally save to file
with open("../python-app/data/billing_year_2024_complete.json", "w", encoding="utf-8") as f:
    json.dump(complete_json, f, indent=2, ensure_ascii=False)

print(f"\n✅ Saved complete billing year data to ../python-app/data/billing_year_2024_complete.json")
# Out:
# {
#   "start_month": 5,
#   "start_year": 2024,
#   "num_months": 12,
#   "billing_months": [
#     {
#       "year": 2024,
#       "month": 5,
#       "month_label": {
#         "month_name": "May",
#         "year": 2024
#       },
#       "main": {
#         "nem2a_meter_type": "GenerationMeter",
#         "billing_date": {
#           "value": "2024-05-14"
#         },
#         "service_end_date": {
#           "value": "2024-05-07"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               -113.82484725050917
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -884.1751527494908
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -998.0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               88.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               294.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               382.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -56.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -435.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -491.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               32.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -141.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -109.0
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               4.79008
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -17.75331
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -12.96323
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -1.41
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             -14.37323
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             24.37
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": [
#             -24.4
#           ]
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": [
#             11.7
#           ]
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": [
#             1.11
#           ]
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": [
#             -11.59
#           ]
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": [
#             60.0
#           ]
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": [
#             7.83
#           ]
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             67.83
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             67.83
#           ]
#         }
#       },
#       "adu": {
#         "nem2a_meter_type": "BenefitMeter",
#         "billing_date": {
#           "value": "2024-05-14"
#         },
#         "service_end_date": {
#           "value": "2024-05-07"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               96.82484725050917
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               298.17515274949085
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               395.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -57.824847250509166
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -449.17515274949085
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -507.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               39.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -151.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -112.0
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               5.83791
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -19.01241
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -13.174499999999998
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -1.51
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             -14.684499999999998
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             14.68
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": []
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": []
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": []
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": []
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": []
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             7.83
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             7.83
#           ]
#         }
#       }
#     },
#     {
#       "year": 2024,
#       "month": 6,
#       "month_label": {
#         "month_name": "June",
#         "year": 2024
#       },
#       "main": {
#         "nem2a_meter_type": "GenerationMeter",
#         "billing_date": {
#           "value": "2024-06-13"
#         },
#         "service_end_date": {
#           "value": "2024-06-06"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               -190.3566958698373
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -1410.6433041301627
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -1601.0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               104.0,
#               17.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               273.0,
#               57.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               451.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -77.0,
#               -18.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -573.0,
#               -131.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -799.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               27.0,
#               -1.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -300.0,
#               -74.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -273.0,
#               -75.0
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               4.04163,
#               -0.19586
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -37.772999999999996,
#               -10.03366
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -43.96088999999999
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -3.75
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             -47.71088999999999
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             72.08
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": [
#             -98.9
#           ]
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": [
#             33.86
#           ]
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": [
#             -1.43
#           ]
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": [
#             -66.47
#           ]
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": [
#             10.0
#           ]
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": [
#             11.75
#           ]
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             21.75
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             21.75
#           ]
#         }
#       },
#       "adu": {
#         "nem2a_meter_type": "BenefitMeter",
#         "billing_date": {
#           "value": "2024-06-13"
#         },
#         "service_end_date": {
#           "value": "2024-06-06"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               102.3566958698373
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               348.64330413016273
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               451.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -95.3566958698373
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -706.6433041301627
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -802.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               13.0,
#               -6.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -269.0,
#               -89.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -256.0,
#               -95.0
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               1.94597,
#               -1.17516
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -33.86979,
#               -12.067509999999999
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -45.16649
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -3.64
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             -48.806490000000004
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             63.49
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": []
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": []
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": []
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": []
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": []
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             11.75
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             11.75
#           ]
#         }
#       }
#     },
#     {
#       "year": 2024,
#       "month": 7,
#       "month_label": {
#         "month_name": "July",
#         "year": 2024
#       },
#       "main": {
#         "nem2a_meter_type": "GenerationMeter",
#         "billing_date": {
#           "value": "2024-07-15"
#         },
#         "service_end_date": {
#           "value": "2024-07-08"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               -202.51766784452295
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -1547.4823321554768
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -1750.0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               180.0,
#               70.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               279.0,
#               114.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               643.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -109.0,
#               -22.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -775.0,
#               -226.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -1132.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               119.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -608.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -489.0
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               23.30734
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -82.43871999999999
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -59.13137999999999
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -6.08
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             -65.21137999999999
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             65.21
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": [
#             -148.92
#           ]
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": [
#             23.84
#           ]
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": [
#             -1.88
#           ]
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": [
#             -126.95999999999998
#           ]
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": [
#             10.0
#           ]
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": [
#             12.53
#           ]
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             22.53
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             22.53
#           ]
#         }
#       },
#       "adu": {
#         "nem2a_meter_type": "BenefitMeter",
#         "billing_date": {
#           "value": "2024-07-15"
#         },
#         "service_end_date": {
#           "value": "2024-07-08"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               52.51766784452295
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               276.4823321554768
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               329.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -71.51766784452295
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -546.4823321554768
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -618.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -19.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -270.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -289.0
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               -3.72134
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -36.6093
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -40.330639999999995
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -2.89
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             -43.220639999999996
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             106.71
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": []
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": []
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": []
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": []
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": []
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             12.53
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             12.53
#           ]
#         }
#       }
#     },
#     {
#       "year": 2024,
#       "month": 8,
#       "month_label": {
#         "month_name": "August",
#         "year": 2024
#       },
#       "main": {
#         "nem2a_meter_type": "GenerationMeter",
#         "billing_date": {
#           "value": "2024-08-16"
#         },
#         "service_end_date": {
#           "value": "2024-08-06"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               -178.0177619893428
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -1213.9822380106573
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -1392.0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               158.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               224.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               382.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -72.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -491.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -563.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               68.2069,
#               17.7931
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -55.2414,
#               -211.7586
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               12.965500000000006,
#               -193.9655
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               13.359003434000002,
#               3.5587979309999995
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -6.693048024,
#               -28.712348573999996
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -18.487595232999993
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -2.67
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             -21.157595232999995
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             158.44
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": [
#             -46.8
#           ]
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": [
#             17.72
#           ]
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": [
#             0.24
#           ]
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": [
#             -28.84
#           ]
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": [
#             10.0
#           ]
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": [
#             11.36
#           ]
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             21.36
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             21.36
#           ]
#         }
#       },
#       "adu": {
#         "nem2a_meter_type": "BenefitMeter",
#         "billing_date": {
#           "value": "2024-08-16"
#         },
#         "service_end_date": {
#           "value": "2024-08-06"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               132.0177619893428
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               408.9822380106573
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               541.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -106.0177619893428
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -722.9822380106573
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -829.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               20.6207,
#               5.3793
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -64.9655,
#               -249.0345
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -44.344800000000006,
#               -243.6552
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               4.038770302,
#               1.075913793
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -7.871219980000001,
#               -33.766587855
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -36.523123739999996
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -3.14
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             -39.663123739999996
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             146.37
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": []
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": []
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": []
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": []
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": []
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             11.36
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             11.36
#           ]
#         }
#       }
#     },
#     {
#       "year": 2024,
#       "month": 9,
#       "month_label": {
#         "month_name": "September",
#         "year": 2024
#       },
#       "main": {
#         "nem2a_meter_type": "GenerationMeter",
#         "billing_date": {
#           "value": "2024-09-17"
#         },
#         "service_end_date": {
#           "value": "2024-09-05"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               -173.45537757437071
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -1339.0755148741418
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -1516.0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               128.0,
#               17.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               149.0,
#               26.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               320.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -44.0,
#               -6.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -317.0,
#               -69.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -437.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               69.0,
#               62.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -145.0,
#               2.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -76.0,
#               64.0
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               13.80069,
#               8.86352
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -17.5682,
#               0.23522
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               5.331229999999998
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -2.11
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             3.221229999999998
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             167.11
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": [
#             -27.53
#           ]
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": [
#             11.37
#           ]
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": [
#             0.64
#           ]
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": [
#             -15.520000000000001
#           ]
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": [
#             10.0
#           ]
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": [
#             11.75
#           ]
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             21.75
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             21.75
#           ]
#         }
#       },
#       "adu": {
#         "nem2a_meter_type": "BenefitMeter",
#         "billing_date": {
#           "value": "2024-09-17"
#         },
#         "service_end_date": {
#           "value": "2024-09-05"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               255.45537757437071
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               632.0755148741418
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               726.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -123.45537757437071
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -953.0755148741418
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -1079.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               99.0,
#               33.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -275.0,
#               -46.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -176.0,
#               -13.0
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               19.80099,
#               4.7176800000000005
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -33.319,
#               -5.4100600000000005
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -14.210390000000004
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -4.34
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             -18.550390000000004
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             187.29
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": []
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": []
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": []
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": []
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": []
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             11.75
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             11.75
#           ]
#         }
#       }
#     },
#     {
#       "year": 2024,
#       "month": 10,
#       "month_label": {
#         "month_name": "October",
#         "year": 2024
#       },
#       "main": {
#         "nem2a_meter_type": "GenerationMeter",
#         "billing_date": {
#           "value": "2024-10-16"
#         },
#         "service_end_date": {
#           "value": "2024-10-06"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               -93.31111111111112
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -1198.6888888888889
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -1292.0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               92.0,
#               65.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               129.0,
#               62.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               348.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -23.0,
#               -3.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -274.0,
#               -60.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -360.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               131.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -143.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -12.0
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               22.664209999999997
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -17.33298
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               5.331229999999998
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -1.45
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             3.8812299999999977
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             163.23
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": [
#             4.42
#           ]
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": [
#             1.01
#           ]
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": [
#             2.1
#           ]
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": [
#             7.53
#           ]
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": [
#             10.0
#           ]
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": [
#             12.14
#           ]
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             22.14
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             -55.17
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             -33.03
#           ]
#         }
#       },
#       "adu": {
#         "nem2a_meter_type": "BenefitMeter",
#         "billing_date": {
#           "value": "2024-10-16"
#         },
#         "service_end_date": {
#           "value": "2024-10-06"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               199.31111111111113
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               543.6888888888889
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               743.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -67.31111111111112
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -864.6888888888889
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -932.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               132.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -321.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -189.0
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               24.51867
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -38.729060000000004
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -14.210390000000004
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -3.21
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             -17.420390000000005
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             204.71
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": []
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": []
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": []
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": []
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": []
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             12.14
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             -55.17
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             -43.03
#           ]
#         }
#       }
#     },
#     {
#       "year": 2024,
#       "month": 11,
#       "month_label": {
#         "month_name": "November",
#         "year": 2024
#       },
#       "main": {
#         "nem2a_meter_type": "GenerationMeter",
#         "billing_date": {
#           "value": "2024-11-14"
#         },
#         "service_end_date": {
#           "value": "2024-11-04"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               -16.638655462184875
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -973.3613445378152
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -990.0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               197.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               219.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               416.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -6.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -351.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
# ...
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": []
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": []
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             11.36
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             88.07
#           ]
#         }
#       }
#     },
#     {
#       "year": 2025,
#       "month": 3,
#       "month_label": {
#         "month_name": "March",
#         "year": 2025
#       },
#       "main": {
#         "nem2a_meter_type": "GenerationMeter",
#         "billing_date": {
#           "value": "2025-03-14"
#         },
#         "service_end_date": {
#           "value": "2025-03-06"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               -2.498360655737705
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -759.5016393442623
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -762.0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               204.0,
#               82.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               268.0,
#               53.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               607.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -1.0,
#               0.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -239.0,
#               -65.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -305.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               237.5,
#               47.5
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               14.1667,
#               2.8333
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               302.0
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               32.16,
#               6.79
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               1.58,
#               0.33
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               40.86
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.09
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             40.95
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             40.95
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": [
#             106.04
#           ]
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": [
#             -30.72
#           ]
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": [
#             6.77
#           ]
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": [
#             82.09
#           ]
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": [
#             10.0
#           ]
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": [
#             11.82
#           ]
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": [
#             40.95
#           ]
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             21.82
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             62.77
#           ]
#         }
#       },
#       "adu": {
#         "nem2a_meter_type": "BenefitMeter",
#         "billing_date": {
#           "value": "2025-03-14"
#         },
#         "service_end_date": {
#           "value": "2025-03-06"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               242.4983606557377
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               591.5016393442623
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               834.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -1.498360655737705
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -455.50163934426234
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -457.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               200.8333,
#               40.1667
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               113.3333,
#               22.6667
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               314.1666,
#               62.8334
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               27.198853819,
#               5.742231432
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               12.627596286,
#               2.665830587
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               48.234512124
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.11
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             48.344512124
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             48.344512124
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": []
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": []
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": []
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": []
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": []
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             11.82
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             60.164512124
#           ]
#         }
#       }
#     },
#     {
#       "year": 2025,
#       "month": 4,
#       "month_label": {
#         "month_name": "April",
#         "year": 2025
#       },
#       "main": {
#         "nem2a_meter_type": "GenerationMeter",
#         "billing_date": {
#           "value": "2025-04-16"
#         },
#         "service_end_date": {
#           "value": "2025-04-06"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               -97.15590200445433
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -1081.8440979955456
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -1179.0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               213.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               265.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               478.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -37.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -412.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -449.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               176.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -147.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               29.0
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               23.84
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -16.38
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               7.460000000000001
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -1.47
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.18
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             6.170000000000001
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             6.0
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": [
#             236.95
#           ]
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": [
#             10.0
#           ]
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": [
#             12.5
#           ]
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": [
#             6.0
#           ]
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             259.45
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             -58.23
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             207.22
#           ]
#         }
#       },
#       "adu": {
#         "nem2a_meter_type": "BenefitMeter",
#         "billing_date": {
#           "value": "2025-04-16"
#         },
#         "service_end_date": {
#           "value": "2025-04-06"
#         },
#         "energy_export_meter_channel_2": {
#           "peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               0
#             ]
#           }
#         },
#         "energy_import_meter_channel_1": {
#           "peak": {
#             "subcomponent_values": [
#               212.15590200445433
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               581.8440979955456
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               794.0
#             ]
#           }
#         },
#         "allocated_export_energy_credits": {
#           "peak": {
#             "subcomponent_values": [
#               -60.15590200445433
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -669.8440979955456
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               -730.0
#             ]
#           }
#         },
#         "net_energy_usage_after_credits": {
#           "peak": {
#             "subcomponent_values": [
#               152.0
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -88.0
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               64.0
#             ]
#           }
#         },
#         "pce_energy_cost": {
#           "peak": {
#             "subcomponent_values": [
#               20.59
#             ]
#           },
#           "off_peak": {
#             "subcomponent_values": [
#               -9.8
#             ]
#           },
#           "total": {
#             "subcomponent_values": [
#               10.79
#             ]
#           }
#         },
#         "pce_net_generation_bonus": {
#           "subcomponent_values": [
#             -0.88
#           ]
#         },
#         "pce_energy_commission_surcharge": {
#           "subcomponent_values": [
#             0.02
#           ]
#         },
#         "pce_total_energy_charges": {
#           "subcomponent_values": [
#             9.929999999999998
#           ]
#         },
#         "pce_nem_credit": {
#           "subcomponent_values": [
#             0.0
#           ]
#         },
#         "pce_generation_charges_due_cash": {
#           "subcomponent_values": [
#             9.93
#           ]
#         },
#         "pge_res_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_baseline_credit": {
#           "subcomponent_values": []
#         },
#         "pge_da_cca_charges": {
#           "subcomponent_values": []
#         },
#         "pge_total_energy_charges": {
#           "subcomponent_values": []
#         },
#         "pge_nem_billing": {
#           "subcomponent_values": []
#         },
#         "pge_minimum_delivery_charge": {
#           "subcomponent_values": []
#         },
#         "pge_nem_true_up_adjustment": {
#           "subcomponent_values": []
#         },
#         "pge_electric_delivery_charges": {
#           "subcomponent_values": [
#             369.51
#           ]
#         },
#         "california_climate_credit": {
#           "subcomponent_values": [
#             -58.23
#           ]
#         },
#         "total_bill_in_mail": {
#           "subcomponent_values": [
#             321.21
#           ]
#         }
#       }
#     }
#   ]
# }
#
# ✅ Saved complete billing year data to ../python-app/data/billing_year_2024_complete.json

# %%
import json

def serialize_where_found_metadata(billing_year):
    """
    Create a metadata structure showing WhereFound information for all EnergyDate and EnergyMetric fields.
    """
    
    def serialize_where_found(wf):
        """Serialize a single WhereFound object"""
        if wf is None:
            return None
        return {
            "where_from": wf.where_from.name if wf.where_from else None,
            "where_on_pdf": wf.where_on_pdf,
            "kevins_number_code": wf.kevins_number_code
        }
    
    def get_field_metadata(field_obj, field_name, field_type):
        """Get metadata for an EnergyDate or EnergyMetric field"""
        return {
            "field_name": field_name,
            "field_type": field_type,
            **({"field_unit": field_obj.unit} if hasattr(field_obj, "unit") else {}),
            "where_found": [serialize_where_found(wf) for wf in field_obj.where_found]
        }
    
    def get_tou_metadata(tou_obj, field_name):
        """Get metadata for an EnergyMetricTOU field"""
        return {
            "field_name": field_name,
            "field_type": "EnergyMetricTOU",
            "peak": get_field_metadata(tou_obj.peak, f"{field_name}.peak", "EnergyMetric"),
            "off_peak": get_field_metadata(tou_obj.off_peak, f"{field_name}.off_peak", "EnergyMetric"),
            "total": get_field_metadata(tou_obj.total, f"{field_name}.total", "EnergyMetric")
        }
    
    def get_meter_metadata(meter):
        """Get metadata for a MeterBillingMonth (main or adu)"""
        return [
            get_field_metadata(meter.billing_date, "billing_date", "EnergyDate"),
            get_field_metadata(meter.service_end_date, "service_end_date", "EnergyDate"),
            get_tou_metadata(meter.energy_export_meter_channel_2, "energy_export_meter_channel_2"),
            get_tou_metadata(meter.energy_import_meter_channel_1, "energy_import_meter_channel_1"),
            get_tou_metadata(meter.allocated_export_energy_credits, "allocated_export_energy_credits"),
            get_tou_metadata(meter.net_energy_usage_after_credits, "net_energy_usage_after_credits"),
            get_tou_metadata(meter.pce_energy_cost, "pce_energy_cost"),
            get_field_metadata(meter.pce_net_generation_bonus, "pce_net_generation_bonus", "EnergyMetric"),
            get_field_metadata(meter.pce_energy_commission_surcharge, "pce_energy_commission_surcharge", "EnergyMetric"),
            get_field_metadata(meter.pce_total_energy_charges, "pce_total_energy_charges", "EnergyMetric"),
            get_field_metadata(meter.pce_nem_credit, "pce_nem_credit", "EnergyMetric"),
            get_field_metadata(meter.pce_generation_charges_due_cash, "pce_generation_charges_due_cash", "EnergyMetric"),
            get_field_metadata(meter.pge_res_energy_charges, "pge_res_energy_charges", "EnergyMetric"),
            get_field_metadata(meter.pge_baseline_credit, "pge_baseline_credit", "EnergyMetric"),
            get_field_metadata(meter.pge_da_cca_charges, "pge_da_cca_charges", "EnergyMetric"),
            get_field_metadata(meter.pge_total_energy_charges, "pge_total_energy_charges", "EnergyMetric"),
            get_field_metadata(meter.pge_nem_billing, "pge_nem_billing", "EnergyMetric"),
            get_field_metadata(meter.pge_minimum_delivery_charge, "pge_minimum_delivery_charge", "EnergyMetric"),
            get_field_metadata(meter.pge_nem_true_up_adjustment, "pge_nem_true_up_adjustment", "EnergyMetric"),
            get_field_metadata(meter.pge_electric_delivery_charges, "pge_electric_delivery_charges", "EnergyMetric"),
            get_field_metadata(meter.california_climate_credit, "california_climate_credit", "EnergyMetric"),
            get_field_metadata(meter.total_bill_in_mail, "total_bill_in_mail", "EnergyMetric")
        ]
    
    # Create a sample month to get the metadata structure (all months have the same structure)
    sample_month_tuple = billing_year.get_months_as_tuples()[0]
    sample_month = billing_year.billing_months[sample_month_tuple]
    
    metadata = {
        "GenerationMeter": get_meter_metadata(sample_month.main),
        "BenefitMeter": get_meter_metadata(sample_month.adu)
    }
    
    return metadata

# Generate and print the metadata
metadata = serialize_where_found_metadata(billing_year_2024)
print(json.dumps(metadata, indent=2))

# Save to file
with open("../python-app/data/billing_structure_metadata.json", "w", encoding="utf-8") as f:
    json.dump(metadata, f, indent=2, ensure_ascii=False)

print(f"\n✅ Saved metadata to ../python-app/data/billing_structure_metadata.json")
# Out:
# {
#   "GenerationMeter": [
#     {
#       "field_name": "billing_date",
#       "field_type": "EnergyDate",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Header",
#           "kevins_number_code": 43
#         }
#       ]
#     },
#     {
#       "field_name": "service_end_date",
#       "field_type": "EnergyDate",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Generation Charges",
#           "kevins_number_code": null
#         },
#         {
#           "where_from": "PDF_DETAIL_OF_BILL",
#           "where_on_pdf": "Page 1",
#           "kevins_number_code": 44
#         }
#       ]
#     },
#     {
#       "field_name": "energy_export_meter_channel_2",
#       "field_type": "EnergyMetricTOU",
#       "peak": {
#         "field_name": "energy_export_meter_channel_2.peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "CALCULATED",
#             "where_on_pdf": null,
#             "kevins_number_code": null
#           }
#         ]
#       },
#       "off_peak": {
#         "field_name": "energy_export_meter_channel_2.off_peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "CALCULATED",
#             "where_on_pdf": null,
#             "kevins_number_code": null
#           }
#         ]
#       },
#       "total": {
#         "field_name": "energy_export_meter_channel_2.total",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_DETAIL_OF_BILL",
#             "where_on_pdf": "Page 3",
#             "kevins_number_code": 15
#           }
#         ]
#       }
#     },
#     {
#       "field_name": "energy_import_meter_channel_1",
#       "field_type": "EnergyMetricTOU",
#       "peak": {
#         "field_name": "energy_import_meter_channel_1.peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_DETAIL_OF_BILL",
#             "where_on_pdf": "Page 5",
#             "kevins_number_code": 4
#           }
#         ]
#       },
#       "off_peak": {
#         "field_name": "energy_import_meter_channel_1.off_peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_DETAIL_OF_BILL",
#             "where_on_pdf": "Page 5",
#             "kevins_number_code": 3
#           }
#         ]
#       },
#       "total": {
#         "field_name": "energy_import_meter_channel_1.total",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_DETAIL_OF_BILL",
#             "where_on_pdf": "Page 3",
#             "kevins_number_code": 10
#           }
#         ]
#       }
#     },
#     {
#       "field_name": "allocated_export_energy_credits",
#       "field_type": "EnergyMetricTOU",
#       "peak": {
#         "field_name": "allocated_export_energy_credits.peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_DETAIL_OF_BILL",
#             "where_on_pdf": "Page 5",
#             "kevins_number_code": 6
#           }
#         ]
#       },
#       "off_peak": {
#         "field_name": "allocated_export_energy_credits.off_peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_DETAIL_OF_BILL",
#             "where_on_pdf": "Page 5",
#             "kevins_number_code": 5
#           }
#         ]
#       },
#       "total": {
#         "field_name": "allocated_export_energy_credits.total",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_DETAIL_OF_BILL",
#             "where_on_pdf": "Page 3",
#             "kevins_number_code": 14
#           }
#         ]
#       }
#     },
#     {
#       "field_name": "net_energy_usage_after_credits",
#       "field_type": "EnergyMetricTOU",
#       "peak": {
#         "field_name": "net_energy_usage_after_credits.peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_BILL",
#             "where_on_pdf": "Generation Charges",
#             "kevins_number_code": 22
#           },
#           {
#             "where_from": "PDF_DETAIL_OF_BILL",
#             "where_on_pdf": "Page 6",
#             "kevins_number_code": null
#           }
#         ]
#       },
#       "off_peak": {
#         "field_name": "net_energy_usage_after_credits.off_peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_BILL",
#             "where_on_pdf": "Generation Charges",
#             "kevins_number_code": 23
#           },
#           {
#             "where_from": "PDF_DETAIL_OF_BILL",
#             "where_on_pdf": "Page 6",
#             "kevins_number_code": null
#           }
#         ]
#       },
#       "total": {
#         "field_name": "net_energy_usage_after_credits.total",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_DETAIL_OF_BILL",
#             "where_on_pdf": "Page 6",
#             "kevins_number_code": 7
#           }
#         ]
#       }
#     },
#     {
#       "field_name": "pce_energy_cost",
#       "field_type": "EnergyMetricTOU",
#       "peak": {
#         "field_name": "pce_energy_cost.peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "$",
#         "where_found": [
#           {
#             "where_from": "PDF_BILL",
#             "where_on_pdf": "Generation Charges",
#             "kevins_number_code": 34
#           }
#         ]
#       },
#       "off_peak": {
#         "field_name": "pce_energy_cost.off_peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "$",
#         "where_found": [
#           {
#             "where_from": "PDF_BILL",
#             "where_on_pdf": "Generation Charges",
#             "kevins_number_code": 33
#           }
#         ]
#       },
#       "total": {
#         "field_name": "pce_energy_cost.total",
#         "field_type": "EnergyMetric",
#         "field_unit": "$",
#         "where_found": [
#           {
#             "where_from": "CALCULATED",
#             "where_on_pdf": null,
#             "kevins_number_code": null
#           }
#         ]
#       }
#     },
#     {
#       "field_name": "pce_net_generation_bonus",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Generation Charges",
#           "kevins_number_code": 37
#         }
#       ]
#     },
#     {
#       "field_name": "pce_energy_commission_surcharge",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Generation Charges",
#           "kevins_number_code": 35
#         }
#       ]
#     },
#     {
#       "field_name": "pce_total_energy_charges",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "CALCULATED",
#           "where_on_pdf": null,
#           "kevins_number_code": null
#         }
#       ]
#     },
#     {
#       "field_name": "pce_nem_credit",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Generation Charges",
#           "kevins_number_code": 36
#         }
#       ]
#     },
#     {
#       "field_name": "pce_generation_charges_due_cash",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Generation Charges",
#           "kevins_number_code": 80
#         }
#       ]
#     },
#     {
#       "field_name": "pge_res_energy_charges",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_DETAIL_OF_BILL",
#           "where_on_pdf": "Page 4",
#           "kevins_number_code": 31
#         }
#       ]
#     },
#     {
#       "field_name": "pge_baseline_credit",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_DETAIL_OF_BILL",
#           "where_on_pdf": "Page 4",
#           "kevins_number_code": 32
#         }
#       ]
#     },
#     {
#       "field_name": "pge_da_cca_charges",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_DETAIL_OF_BILL",
#           "where_on_pdf": "Page 4",
#           "kevins_number_code": 38
#         }
#       ]
#     },
#     {
#       "field_name": "pge_total_energy_charges",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_DETAIL_OF_BILL",
#           "where_on_pdf": "Page 4",
#           "kevins_number_code": 39
#         }
#       ]
#     },
#     {
#       "field_name": "pge_nem_billing",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_DETAIL_OF_BILL",
#           "where_on_pdf": "Page 4",
#           "kevins_number_code": 40
#         }
#       ]
#     },
#     {
#       "field_name": "pge_minimum_delivery_charge",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_DETAIL_OF_BILL",
#           "where_on_pdf": "Page 4",
#           "kevins_number_code": 41
#         }
#       ]
#     },
#     {
#       "field_name": "pge_nem_true_up_adjustment",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_DETAIL_OF_BILL",
#           "where_on_pdf": "Page 1 - True Up Only",
#           "kevins_number_code": 80
#         }
#       ]
#     },
#     {
#       "field_name": "pge_electric_delivery_charges",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Electric Delivery Charges",
#           "kevins_number_code": 30
#         },
#         {
#           "where_from": "PDF_DETAIL_OF_BILL",
#           "where_on_pdf": "Page 4",
#           "kevins_number_code": null
#         }
#       ]
#     },
#     {
#       "field_name": "california_climate_credit",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Electric Delivery Charges",
#           "kevins_number_code": 45
#         }
#       ]
#     },
#     {
#       "field_name": "total_bill_in_mail",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "CALCULATED",
#           "where_on_pdf": null,
#           "kevins_number_code": null
#         }
#       ]
#     }
#   ],
#   "BenefitMeter": [
#     {
#       "field_name": "billing_date",
#       "field_type": "EnergyDate",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Header",
#           "kevins_number_code": 43
#         }
#       ]
#     },
#     {
#       "field_name": "service_end_date",
#       "field_type": "EnergyDate",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Generation Charges",
#           "kevins_number_code": null
#         },
#         {
#           "where_from": "PDF_DETAIL_OF_BILL",
#           "where_on_pdf": "Page 1",
#           "kevins_number_code": 44
#         }
#       ]
#     },
#     {
#       "field_name": "energy_export_meter_channel_2",
#       "field_type": "EnergyMetricTOU",
#       "peak": {
#         "field_name": "energy_export_meter_channel_2.peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "FIXED_VALUE",
#             "where_on_pdf": null,
#             "kevins_number_code": null
#           }
#         ]
#       },
#       "off_peak": {
#         "field_name": "energy_export_meter_channel_2.off_peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "FIXED_VALUE",
#             "where_on_pdf": null,
#             "kevins_number_code": null
#           }
#         ]
#       },
#       "total": {
#         "field_name": "energy_export_meter_channel_2.total",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "FIXED_VALUE",
#             "where_on_pdf": null,
#             "kevins_number_code": null
#           }
#         ]
#       }
#     },
#     {
#       "field_name": "energy_import_meter_channel_1",
#       "field_type": "EnergyMetricTOU",
#       "peak": {
#         "field_name": "energy_import_meter_channel_1.peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "CALCULATED",
#             "where_on_pdf": null,
#             "kevins_number_code": null
#           }
#         ]
#       },
#       "off_peak": {
#         "field_name": "energy_import_meter_channel_1.off_peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "CALCULATED",
#             "where_on_pdf": null,
#             "kevins_number_code": null
#           }
#         ]
#       },
#       "total": {
#         "field_name": "energy_import_meter_channel_1.total",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_DETAIL_OF_BILL",
#             "where_on_pdf": "Page 3",
#             "kevins_number_code": 9
#           }
#         ]
#       }
#     },
#     {
#       "field_name": "allocated_export_energy_credits",
#       "field_type": "EnergyMetricTOU",
#       "peak": {
#         "field_name": "allocated_export_energy_credits.peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "CALCULATED",
#             "where_on_pdf": null,
#             "kevins_number_code": null
#           }
#         ]
#       },
#       "off_peak": {
#         "field_name": "allocated_export_energy_credits.off_peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "CALCULATED",
#             "where_on_pdf": null,
#             "kevins_number_code": null
#           }
#         ]
#       },
#       "total": {
#         "field_name": "allocated_export_energy_credits.total",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_DETAIL_OF_BILL",
#             "where_on_pdf": "Page 3",
#             "kevins_number_code": 13
#           }
#         ]
#       }
#     },
#     {
#       "field_name": "net_energy_usage_after_credits",
#       "field_type": "EnergyMetricTOU",
#       "peak": {
#         "field_name": "net_energy_usage_after_credits.peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_BILL",
#             "where_on_pdf": "Generation Charges",
#             "kevins_number_code": 20
#           }
#         ]
#       },
#       "off_peak": {
#         "field_name": "net_energy_usage_after_credits.off_peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_BILL",
#             "where_on_pdf": "Generation Charges",
#             "kevins_number_code": 21
#           }
#         ]
#       },
#       "total": {
#         "field_name": "net_energy_usage_after_credits.total",
#         "field_type": "EnergyMetric",
#         "field_unit": "kWh",
#         "where_found": [
#           {
#             "where_from": "PDF_DETAIL_OF_BILL",
#             "where_on_pdf": "Page 6",
#             "kevins_number_code": 8
#           }
#         ]
#       }
#     },
#     {
#       "field_name": "pce_energy_cost",
#       "field_type": "EnergyMetricTOU",
#       "peak": {
#         "field_name": "pce_energy_cost.peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "$",
#         "where_found": [
#           {
#             "where_from": "PDF_BILL",
#             "where_on_pdf": "Generation Charges",
#             "kevins_number_code": 25
#           }
#         ]
#       },
#       "off_peak": {
#         "field_name": "pce_energy_cost.off_peak",
#         "field_type": "EnergyMetric",
#         "field_unit": "$",
#         "where_found": [
#           {
#             "where_from": "PDF_BILL",
#             "where_on_pdf": "Generation Charges",
#             "kevins_number_code": 24
#           }
#         ]
#       },
#       "total": {
#         "field_name": "pce_energy_cost.total",
#         "field_type": "EnergyMetric",
#         "field_unit": "$",
#         "where_found": [
#           {
#             "where_from": "CALCULATED",
#             "where_on_pdf": null,
#             "kevins_number_code": null
#           }
#         ]
#       }
#     },
#     {
#       "field_name": "pce_net_generation_bonus",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Generation Charges",
#           "kevins_number_code": 26
#         }
#       ]
#     },
#     {
#       "field_name": "pce_energy_commission_surcharge",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Generation Charges",
#           "kevins_number_code": 27
#         }
#       ]
#     },
#     {
#       "field_name": "pce_total_energy_charges",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "CALCULATED",
#           "where_on_pdf": null,
#           "kevins_number_code": null
#         }
#       ]
#     },
#     {
#       "field_name": "pce_nem_credit",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Generation Charges",
#           "kevins_number_code": 28
#         }
#       ]
#     },
#     {
#       "field_name": "pce_generation_charges_due_cash",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Generation Charges",
#           "kevins_number_code": 29
#         }
#       ]
#     },
#     {
#       "field_name": "pge_res_energy_charges",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "NOT_PROVIDED",
#           "where_on_pdf": null,
#           "kevins_number_code": null
#         }
#       ]
#     },
#     {
#       "field_name": "pge_baseline_credit",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "NOT_PROVIDED",
#           "where_on_pdf": null,
#           "kevins_number_code": null
#         }
#       ]
#     },
#     {
#       "field_name": "pge_da_cca_charges",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "NOT_PROVIDED",
#           "where_on_pdf": null,
#           "kevins_number_code": null
#         }
#       ]
#     },
#     {
#       "field_name": "pge_total_energy_charges",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "NOT_PROVIDED",
#           "where_on_pdf": null,
#           "kevins_number_code": null
#         }
#       ]
#     },
#     {
#       "field_name": "pge_nem_billing",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "NOT_PROVIDED",
#           "where_on_pdf": null,
#           "kevins_number_code": null
#         }
#       ]
#     },
#     {
#       "field_name": "pge_minimum_delivery_charge",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "NOT_PROVIDED",
#           "where_on_pdf": null,
#           "kevins_number_code": null
#         }
#       ]
#     },
#     {
#       "field_name": "pge_nem_true_up_adjustment",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "NOT_PROVIDED",
#           "where_on_pdf": null,
#           "kevins_number_code": null
#         }
#       ]
#     },
#     {
#       "field_name": "pge_electric_delivery_charges",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Electric Delivery Charges",
#           "kevins_number_code": 42
#         }
#       ]
#     },
#     {
#       "field_name": "california_climate_credit",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "PDF_BILL",
#           "where_on_pdf": "Electric Delivery Charges",
#           "kevins_number_code": 46
#         }
#       ]
#     },
#     {
#       "field_name": "total_bill_in_mail",
#       "field_type": "EnergyMetric",
#       "field_unit": "$",
#       "where_found": [
#         {
#           "where_from": "CALCULATED",
#           "where_on_pdf": null,
#           "kevins_number_code": null
#         }
#       ]
#     }
#   ]
# }
#
# ✅ Saved metadata to ../python-app/data/billing_structure_metadata.json
