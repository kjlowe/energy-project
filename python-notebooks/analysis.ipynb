# %%
import pandas as pd

# Create a DataFrame with the output
df = pd.DataFrame({"Output": ["hello", "world", "again", "three"]})
display(df)
# Out:
#   Output
# 0  hello
# 1  world
# 2  again
# 3  three

# %%
import pandas as pd

# Read data from Google Sheets
# url = f"https://docs.google.com/spreadsheets/d/1GuHkRddZm5Idxfa-IUlA-lXQFydduyau/gviz/tq?tqx=out:csv&sheet=Billing"
# df = pd.read_csv(url)

# Read data as excel file
# curl -L https://docs.google.com/spreadsheets/d/1GuHkRddZm5Idxfa-IUlA-lXQFydduyau/export?format=xlsx&sheet=Billing --output billing.xlsx

# read excel file billing.xlsx with the following instructions
# - first lin is blank ignore
# - 2, 3, 4, 5, 6 are are headers
df = pd.read_excel("billing.xlsx", header=[1, 2, 5])

# Print the MultiIndex structure
# List all column tuples
print("All Column Tuples:")
for i, col in enumerate(df.columns):
    print(f"Column {i}: {col}")
# Out:
# All Column Tuples:
# Column 0: ('Which Unit', 'Table header', 'Table subheader')
# Column 1: ('Dates', 'Dates', 'Service End Date [Date]')
# Column 2: ('Dates', 'Dates', 'Billing Date [Date]\n(43)')
# Column 3: ('303 Main', 'Meter Export Energy (Solar) \n(channel 2)', 'off peak [kWh]\n(1) ')
# Column 4: ('303 Main', 'Meter Export Energy (Solar) \n(channel 2)', 'peak [kWh]\n(2)')
# Column 5: ('303 Main', 'Meter Export Energy (Solar) \n(channel 2)', 'total [kWh]\n(15)')
# Column 6: ('303 Main', 'Meter Import Energy\n(channel 1)', 'off peak [kWh]\n(3)')
# Column 7: ('303 Main', 'Meter Import Energy\n(channel 1)', 'peak [kWh]\n(4)')
# Column 8: ('303 Main', 'Meter Import Energy\n(channel 1)', 'total [kWh]\n(10)')
# Column 9: ('303 Main', 'Allocated Export Credits', 'off peak [kWh]\n(5)')
# Column 10: ('303 Main', 'Allocated Export Credits', 'peak [kWh]\n(6)')
# Column 11: ('303 Main', 'Allocated Export Credits', 'total [kWh]\n(14)')
# Column 12: ('303 Main', 'Allocated Export Credits', 'allocation [%] (14)/(15)')
# Column 13: ('303 Main', 'Net Energy Usage - After Solar Allocation', 'off peak [kWh]\n(23)')
# Column 14: ('303 Main', 'Net Energy Usage - After Solar Allocation', 'peak\n[kWh]\n(22)')
# Column 15: ('303 Main', 'Net Energy Usage - After Solar Allocation', 'total [kWh]   (7)')
# Column 16: ('303 Main', 'PCE - Peninsula Clean Energy (Energy)', 'PCE - off peak energy\n[$]\n(33)')
# Column 17: ('303 Main', 'PCE - Peninsula Clean Energy (Energy)', 'PCE - peak energy\n[$]\n(34)')
# Column 18: ('303 Main', 'PCE - Peninsula Clean Energy (Energy)', 'PCE - Energy Cost Total\n[$]')
# Column 19: ('303 Main', 'PCE - Peninsula Clean Energy (Energy)', 'PCE - Net Generation Bonus\n[$]\n(37)')
# Column 20: ('303 Main', 'PCE - Peninsula Clean Energy (Energy)', 'PCE - Average Price Per kWh\n[$]')
# Column 21: ('303 Main', 'PCE - Peninsula Clean Energy (Energy)', 'PCE - Peak Price Per kWh\n[$]')
# Column 22: ('303 Main', 'PCE - Peninsula Clean Energy (Energy)', 'PCE - Off Peak Price Per kWh\n[$]')
# Column 23: ('303 Main', 'PCE - Peninsula Clean Energy (Energy)', 'PCE - Total Energy Charges\n[$]')
# Column 24: ('303 Main', 'PCE - Peninsula Clean Energy (Energy)', 'PCE NEM Credit \n[$]\n(36)')
# Column 25: ('303 Main', 'PCE - Peninsula Clean Energy (Energy)', ' PCE Generation Charges due in Cash \n[$]\n(36)')
# Column 26: ('303 Main', 'PG&E - Pacific Gas & Electric (Delivery)', 'RES Energy Charges \n[$]\n(31)')
# Column 27: ('303 Main', 'PG&E - Pacific Gas & Electric (Delivery)', 'Baseline Credit\n[$]\n(32)')
# Column 28: ('303 Main', 'PG&E - Pacific Gas & Electric (Delivery)', 'DA/CCA FEES\n[$]\n(38)')
# Column 29: ('303 Main', 'PG&E - Pacific Gas & Electric (Delivery)', 'PG&E Total "Energy" Charges (ie. Delivery)\n[$]\n(39)')
# Column 30: ('303 Main', 'PG&E - Pacific Gas & Electric (Delivery)', 'PG&E - NEM Billing\n[$]\n(40)')
# Column 31: ('303 Main', 'PG&E - Pacific Gas & Electric (Delivery)', 'Minimum Delivery Charge\n[$]\n(41)')
# Column 32: ('303 Main', 'PG&E - Pacific Gas & Electric (Delivery)', 'NEM True Up Adjustment\n[$]')
# Column 33: ('303 Main', 'PG&E - Pacific Gas & Electric (Delivery)', 'PG&E Electric Delivery Charges\n[$]\n(30)')
# Column 34: ('303 Main', 'Other', 'California Climate Credit\n[$]')
# Column 35: ('303 Main', 'Other', 'Total Bill in Mail Monthly  [$]')
# Column 36: ('303A ADU', 'Meter Import Energy\n(channel 1)', 'off peak\n[kWh]')
# Column 37: ('303A ADU', 'Meter Import Energy\n(channel 1)', 'peak\n[kWh]')
# Column 38: ('303A ADU', 'Meter Import Energy\n(channel 1)', 'total\n[kWh]\n(9)')
# Column 39: ('303A ADU', 'Allocated Export Credits ', 'off peak\n[kWh]')
# Column 40: ('303A ADU', 'Allocated Export Credits ', 'peak\n[kWh]')
# Column 41: ('303A ADU', 'Allocated Export Credits ', 'total [kWh]\n(13)')
# Column 42: ('303A ADU', 'Allocated Export Credits ', 'allocation \n[%]\n(13)/(15)')
# Column 43: ('303A ADU', 'Net Energy Usage - After Solar Allocation', 'off peak [kWh]\n(21)')
# Column 44: ('303A ADU', 'Net Energy Usage - After Solar Allocation', 'peak [kWh]\n(20)')
# Column 45: ('303A ADU', 'Net Energy Usage - After Solar Allocation', 'total [kWh]\n(8)')
# Column 46: ('303A ADU', 'PCE - Peninsula Clean Energy', 'PCE - off peak cost [$]\n(24)')
# Column 47: ('303A ADU', 'PCE - Peninsula Clean Energy', 'PCE - peak cost \n[$]\n(25)')
# Column 48: ('303A ADU', 'PCE - Peninsula Clean Energy', 'PCE - Energy Cost Total\n[$]')
# Column 49: ('303A ADU', 'PCE - Peninsula Clean Energy', 'PCE - Net Generation Bonus\n[$]\n(26)')
# Column 50: ('303A ADU', 'PCE - Peninsula Clean Energy', 'Energy Commission Surcharge\n[$]\n(27)')
# Column 51: ('303A ADU', 'PCE - Peninsula Clean Energy', 'PCE - Total Energy Charges\n[$]')
# Column 52: ('303A ADU', 'PCE - Peninsula Clean Energy', 'PCE NEM Credit\n[$]\n(28)')
# Column 53: ('303A ADU', 'PCE - Peninsula Clean Energy', 'PCE Generation Charges due in Cash \n[$]\n(29)')
# Column 54: ('303A ADU', 'PG&E - Pacific Gas & Electric', 'PG&E Electric Delivery Charges [$]\n(42)')
# Column 55: ('303A ADU', 'Other', 'California Climate Credit\n[$]')
# Column 56: ('303A ADU', 'Other', 'Total Bill in Mail Monthly\n[$]')

# %%
df
# Out:
#         Which Unit                   Dates                            \
#       Table header                   Dates
#    Table subheader Service End Date [Date] Billing Date [Date]\n(43)
# 0              NaN              2024-05-07       2024-05-14 00:00:00
# 1              NaN              2024-06-06       2024-06-13 00:00:00
# 2              NaN                     NaT                    winter
# 3              NaN                     NaT                    summer
# 4              NaN              2024-07-08       2024-07-15 00:00:00
# 5              NaN                     NaT       07 - earlier period
# 6              NaN                     NaT         07 - later period
# 7              NaN              2024-08-06       2024-08-16 00:00:00
# 8              NaN                     NaT           08 - old rates
# 9              NaN                     NaT            08 - new rates
# 10             NaN              2024-09-05       2024-09-17 00:00:00
# 11             NaN                     NaT  summer - old rate period
# 12             NaN                     NaT  summer - new rate period
# 13             NaN                     NaT                    summer
# 14             NaN                     NaT                    winter
# 15             NaN              2024-10-06       2024-10-16 00:00:00
# 16             NaN                     NaT                    summer
# 17             NaN                     NaT                    winter
# 18             NaN              2024-11-04       2024-11-14 00:00:00
# 19             NaN              2025-12-05       2024-12-17 00:00:00
# 20             NaN              2025-01-06       2025-01-16 00:00:00
# 21             NaN                     NaT       01 - earlier period
# 22             NaN                     NaT         02 - later period
# 23             NaN              2025-02-04       2025-02-19 00:00:00
# 24             NaN              2025-03-06       2025-03-14 00:00:00
# 25             NaN                     NaT            03 - old rates
# 26             NaN                     NaT            03 - new rates
# 27             NaN              2025-04-06       2025-04-16 00:00:00
#
#                                     303 Main                  \
#    Meter Export Energy (Solar) \n(channel 2)
#                         off peak [kWh]\n(1)  peak [kWh]\n(2)
# 0                                     -884.0          -114.0
# 1                                    -1411.0          -190.0
# 2                                        NaN             NaN
# 3                                        NaN             NaN
# 4                                    -1547.0          -203.0
# 5                                        NaN             NaN
# 6                                        NaN             NaN
# 7                                    -1214.0          -178.0
# 8                                        NaN             NaN
# 9                                        NaN             NaN
# 10                                   -1339.0          -173.0
# 11                                       NaN             NaN
# 12                                       NaN             NaN
# 13                                       NaN             NaN
# 14                                       NaN             NaN
# 15                                   -1199.0           -93.0
# 16                                       NaN             NaN
# 17                                       NaN             NaN
# 18                                    -973.0           -17.0
# 19                                    -605.0             0.0
# 20                                    -309.0             0.0
# 21                                       NaN             NaN
# 22                                       NaN             NaN
# 23                                       0.0             0.0
# 24                                    -760.0            -2.0
# 25                                       NaN             NaN
# 26                                       NaN             NaN
# 27                                   -1082.0           -97.0
#
#                                                                        \
#                      Meter Import Energy\n(channel 1)
#    total [kWh]\n(15)              off peak [kWh]\n(3) peak [kWh]\n(4)
# 0             -998.0                            294.0            88.0
# 1            -1601.0                            330.0           121.0
# 2                NaN                            273.0           104.0
# 3                NaN                             57.0            17.0
# 4            -1750.0                            393.0           250.0
# 5                NaN                            279.0           180.0
# 6                NaN                            114.0            70.0
# 7            -1392.0                            224.0           158.0
# 8                NaN                              NaN             NaN
# 9                NaN                              NaN             NaN
# 10           -1516.0                            175.0           145.0
# 11               NaN                            149.0           128.0
# 12               NaN                             26.0            17.0
# 13               NaN                              NaN             NaN
# 14               NaN                              NaN             NaN
# 15           -1292.0                            191.0           157.0
# 16               NaN                            129.0            92.0
# 17               NaN                             62.0            65.0
# 18            -990.0                            219.0           197.0
# 19            -605.0                            350.0           214.0
# 20            -309.0                            489.0           332.0
# 21               NaN                            370.0           241.0
# 22               NaN                            119.0            91.0
# 23               0.0                            615.0           332.0
# 24            -762.0                            321.0           286.0
# 25               NaN                            268.0           204.0
# 26               NaN                             53.0            82.0
# 27           -1179.0                            265.0           213.0
#
#                                                                \
#                      Allocated Export Credits
#    total [kWh]\n(10)      off peak [kWh]\n(5) peak [kWh]\n(6)
# 0              382.0                   -435.0           -56.0
# 1              451.0                   -704.0           -95.0
# 2                NaN                   -573.0           -77.0
# 3                NaN                   -131.0           -18.0
# 4              643.0                  -1001.0          -131.0
# 5                NaN                   -775.0          -109.0
# 6                NaN                   -226.0           -22.0
# 7              382.0                   -491.0           -72.0
# 8                NaN                      NaN             NaN
# 9                NaN                      NaN             NaN
# 10             320.0                   -386.0           -50.0
# 11               NaN                   -317.0           -44.0
# 12               NaN                    -69.0            -6.0
# 13               NaN                      NaN             NaN
# 14               NaN                      NaN             NaN
# 15             348.0                   -334.0           -26.0
# 16               NaN                   -274.0           -23.0
# 17               NaN                    -60.0            -3.0
# 18             416.0                   -351.0            -6.0
# 19             564.0                   -206.0             0.0
# 20             821.0                   -210.0             0.0
# 21               NaN                   -192.0             0.0
# 22               NaN                    -18.0             0.0
# 23             947.0                      0.0          -190.0
# 24             607.0                   -304.0            -1.0
# 25               NaN                   -239.0            -1.0
# 26               NaN                    -65.0             0.0
# 27             478.0                   -412.0           -37.0
#
#                                                \
#
#    total [kWh]\n(14) allocation [%] (14)/(15)
# 0             -491.0                 0.491984
# 1             -799.0                 0.499063
# 2                NaN                      NaN
# 3                NaN                      NaN
# 4            -1132.0                 0.646857
# 5                NaN                      NaN
# 6                NaN                      NaN
# 7             -563.0                 0.404454
# 8                NaN                      NaN
# 9                NaN                      NaN
# 10            -437.0                 0.288259
# 11               NaN                      NaN
# 12               NaN                      NaN
# 13               NaN                      NaN
# 14               NaN                      NaN
# 15            -360.0                 0.278638
# 16               NaN                      NaN
# 17               NaN                      NaN
# 18            -357.0                 0.360606
# 19            -206.0                 0.340496
# 20            -210.0                 0.679612
# 21               NaN                      NaN
# 22               NaN                      NaN
# 23            -190.0                      NaN
# 24            -305.0                 0.400262
# 25               NaN                      NaN
# 26               NaN                      NaN
# 27            -449.0                 0.380831
#
#                                                                 \
#    Net Energy Usage - After Solar Allocation
#                         off peak [kWh]\n(23) peak\n[kWh]\n(22)
# 0                                  -141.0000           32.0000
# 1                                  -374.0000           26.0000
# 2                                  -300.0000           27.0000
# 3                                   -74.0000           -1.0000
# 4                                  -608.0000          119.0000
# 5                                        NaN               NaN
# 6                                        NaN               NaN
# 7                                  -267.0000           86.0000
# 8                                   -55.2414           68.2069
# 9                                  -211.7586           17.7931
# 10                                 -211.0000           95.0000
# 11                                       NaN               NaN
# 12                                       NaN               NaN
# 13                                 -145.0000           69.0000
# 14                                    2.0000           62.0000
# 15                                 -143.0000          131.0000
# 16                                       NaN               NaN
# 17                                       NaN               NaN
# 18                                 -132.0000          191.0000
# 19                                  144.0000          214.0000
# 20                                  279.0000          332.0000
# 21                                       NaN               NaN
# 22                                       NaN               NaN
# 23                                  615.0000          142.0000
# 24                                   17.0000          285.0000
# 25                                       NaN               NaN
# 26                                       NaN               NaN
# 27                                 -147.0000          176.0000
#
#                                                             \
#                      PCE - Peninsula Clean Energy (Energy)
#    total [kWh]   (7)      PCE - off peak energy\n[$]\n(33)
# 0          -109.0000                            -17.753310
# 1          -348.0000                            -47.806660
# 2          -273.0000                            -37.773000
# 3           -75.0000                            -10.033660
# 4          -489.0000                            -82.438720
# 5                NaN                                   NaN
# 6                NaN                                   NaN
# 7          -181.0000                            -35.405397
# 8            12.9655                             -6.693048
# 9          -193.9655                            -28.712349
# 10         -116.0000                            -25.564760
# 11               NaN                                   NaN
# 12               NaN                                   NaN
# 13          -76.0000                            -17.568200
# 14           64.0000                              0.235220
# 15          -12.0000                            -17.332980
# 16               NaN                                   NaN
# 17               NaN                                   NaN
# 18           59.0000                            -15.524520
# 19          358.0000                             16.935840
# 20          611.0000                             32.813190
# 21               NaN                                   NaN
# 22               NaN                                   NaN
# 23          757.0000                             72.330000
# 24          302.0000                              1.910000
# 25               NaN                              1.580000
# 26               NaN                              0.330000
# 27           29.0000                            -16.380000
#
#                                                               \
#
#    PCE - peak energy\n[$]\n(34) PCE - Energy Cost Total\n[$]
# 0                      4.790080                   -12.963230
# 1                      3.845770                   -43.960890
# 2                      4.041630                          NaN
# 3                     -0.195860                          NaN
# 4                     23.307340                   -59.131380
# 5                           NaN                          NaN
# 6                           NaN                          NaN
# 7                     16.917801                   -18.487595
# 8                     13.359003                          NaN
# 9                      3.558798                          NaN
# 10                    19.000950                    -6.563810
# 11                          NaN                          NaN
# 12                          NaN                          NaN
# 13                    13.800690                          NaN
# 14                     8.863520                          NaN
# 15                    22.664210                     5.331230
# 16                          NaN                          NaN
# 17                          NaN                          NaN
# 18                    27.305360                    11.780840
# 19                    30.593440                    47.529280
# 20                    47.462720                    80.275910
# 21                          NaN                          NaN
# 22                          NaN                          NaN
# 23                    20.300000                    92.630000
# 24                    38.950000                    40.860000
# 25                    32.160000                    33.740000
# 26                     6.790000                     7.120000
# 27                    23.840000                    23.840000
#
#                                                                            \
#
#    PCE - Net Generation Bonus\n[$]\n(37) PCE - Average Price Per kWh\n[$]
# 0                                  -1.41                         0.130309
# 1                                  -3.75                         0.129131
# 2                                    NaN                              NaN
# 3                                    NaN                              NaN
# 4                                  -6.08                         0.145455
# 5                                    NaN                              NaN
# 6                                    NaN                              NaN
# 7                                  -2.67                         0.148224
# 8                                    NaN                              NaN
# 9                                    NaN                              NaN
# 10                                 -2.11                         0.145640
# 11                                   NaN                              NaN
# 12                                   NaN                              NaN
# 13                                   NaN                              NaN
# 14                                   NaN                              NaN
# 15                                 -1.45                         0.145975
# 16                                   NaN                              NaN
# 17                                   NaN                              NaN
# 18                                 -1.32                         0.132600
# 19                                  0.00                         0.132763
# 20                                  0.00                         0.131384
# 21                                   NaN                              NaN
# 22                                   NaN                              NaN
# 23                                -10.00                         0.122365
# 24                                  0.00                         0.135298
# 25                                   NaN                              NaN
# 26                                   NaN                              NaN
# 27                                 -1.47                         0.124520
#
#                                                                     \
#
#    PCE - Peak Price Per kWh\n[$] PCE - Off Peak Price Per kWh\n[$]
# 0                       0.149690                          0.125910
# 1                       0.147914                          0.127825
# 2                            NaN                               NaN
# 3                            NaN                               NaN
# 4                       0.195860                          0.135590
# 5                            NaN                               NaN
# 6                            NaN                               NaN
# 7                       0.196719                          0.132604
# 8                            NaN                               NaN
# 9                            NaN                               NaN
# 10                      0.200010                          0.121160
# 11                           NaN                               NaN
# 12                           NaN                               NaN
# 13                           NaN                               NaN
# 14                           NaN                               NaN
# 15                      0.173009                          0.121210
# 16                           NaN                               NaN
# 17                           NaN                               NaN
# 18                      0.142960                          0.117610
# 19                      0.142960                          0.117610
# 20                      0.142960                          0.117610
# 21                           NaN                               NaN
# 22                           NaN                               NaN
# 23                      0.142958                          0.117610
# 24                      0.136667                          0.112353
# 25                           NaN                               NaN
# 26                           NaN                               NaN
# 27                      0.135455                          0.111429
#
#                                                                \
#
#    PCE - Total Energy Charges\n[$] PCE NEM Credit \n[$]\n(36)
# 0                       -14.373230                      24.37
# 1                       -47.710890                      72.08
# 2                              NaN                        NaN
# 3                              NaN                        NaN
# 4                       -65.211380                      65.21
# 5                              NaN                        NaN
# 6                              NaN                        NaN
# 7                       -21.157595                     158.44
# 8                              NaN                        NaN
# 9                              NaN                        NaN
# 10                       -8.673810                     167.11
# 11                             NaN                        NaN
# 12                             NaN                        NaN
# 13                             NaN                        NaN
# 14                             NaN                        NaN
# 15                        3.881230                     163.23
# 16                             NaN                        NaN
# 17                             NaN                        NaN
# 18                       10.480840                     152.74
# 19                       47.549280                     105.10
# 20                       80.455910                      24.65
# 21                             NaN                        NaN
# 22                             NaN                        NaN
# 23                       82.630000                       0.00
# 24                       40.950000                       0.00
# 25                             NaN                        NaN
# 26                             NaN                        NaN
# 27                        6.170000                       0.00
#
#                                                     \
#
#     PCE Generation Charges due in Cash \n[$]\n(36)
# 0                                             0.00
# 1                                             0.00
# 2                                              NaN
# 3                                              NaN
# 4                                             0.00
# 5                                              NaN
# 6                                              NaN
# 7                                             0.00
# 8                                              NaN
# 9                                              NaN
# 10                                            0.00
# 11                                             NaN
# 12                                             NaN
# 13                                             NaN
# 14                                             NaN
# 15                                            0.00
# 16                                             NaN
# 17                                             NaN
# 18                                            0.00
# 19                                            0.00
# 20                                            0.00
# 21                                             NaN
# 22                                             NaN
# 23                                           68.21
# 24                                           40.95
# 25                                             NaN
# 26                                             NaN
# 27                                            6.00
#
#                                                                         \
#    PG&E - Pacific Gas & Electric (Delivery)
#              RES Energy Charges \n[$]\n(31) Baseline Credit\n[$]\n(32)
# 0                                    -24.40                      11.70
# 1                                    -98.90                      33.86
# 2                                       NaN                        NaN
# 3                                       NaN                        NaN
# 4                                   -148.92                      23.84
# 5                                       NaN                        NaN
# 6                                       NaN                        NaN
# 7                                    -46.80                      17.72
# 8                                       NaN                        NaN
# 9                                       NaN                        NaN
# 10                                   -27.53                      11.37
# 11                                      NaN                        NaN
# 12                                      NaN                        NaN
# 13                                      NaN                        NaN
# 14                                      NaN                        NaN
# 15                                     4.42                       1.01
# 16                                      NaN                        NaN
# 17                                      NaN                        NaN
# 18                                    27.92                      -5.97
# 19                                   120.14                     -36.22
# 20                                   201.73                     -41.77
# 21                                      NaN                        NaN
# 22                                      NaN                        NaN
# 23                                   248.10                     -37.92
# 24                                   106.04                     -30.72
# 25                                      NaN                        NaN
# 26                                      NaN                        NaN
# 27                                     0.00                       0.00
#
#                            \
#
#    DA/CCA FEES\n[$]\n(38)
# 0                    1.11
# 1                   -1.43
# 2                     NaN
# 3                     NaN
# 4                   -1.88
# 5                     NaN
# 6                     NaN
# 7                    0.24
# 8                     NaN
# 9                     NaN
# 10                   0.64
# 11                    NaN
# 12                    NaN
# 13                    NaN
# 14                    NaN
# 15                    2.1
# 16                    NaN
# 17                    NaN
# 18                   3.43
# 19                   8.11
# 20                  12.56
# 21                    NaN
# 22                    NaN
# 23                  14.16
# 24                   6.77
# 25                    NaN
# 26                   sett
# 27                      0
#
#                                                           \
#
#    PG&E Total "Energy" Charges (ie. Delivery)\n[$]\n(39)
# 0                                                 -11.59
# 1                                                 -66.47
# 2                                                    NaN
# 3                                                    NaN
# 4                                                -126.96
# 5                                                    NaN
# 6                                                    NaN
# 7                                                 -28.84
# 8                                                    NaN
# 9                                                    NaN
# 10                                                -15.52
# 11                                                   NaN
# 12                                                   NaN
# 13                                                   NaN
# 14                                                   NaN
# 15                                                  7.53
# 16                                                   NaN
# 17                                                   NaN
# 18                                                 25.38
# 19                                                 92.03
# 20                                                172.52
# 21                                                   NaN
# 22                                                   NaN
# 23                                                224.34
# 24                                                 82.09
# 25                                                   NaN
# 26                                                   NaN
# 27                                                236.95
#
#                                                                      \
#
#    PG&E - NEM Billing\n[$]\n(40) Minimum Delivery Charge\n[$]\n(41)
# 0                           60.0                               7.83
# 1                           10.0                              11.75
# 2                            NaN                                NaN
# 3                            NaN                                NaN
# 4                           10.0                              12.53
# 5                            NaN                                NaN
# 6                            NaN                                NaN
# 7                           10.0                              11.36
# 8                            NaN                                NaN
# 9                            NaN                                NaN
# 10                          10.0                              11.75
# 11                           NaN                                NaN
# 12                           NaN                                NaN
# 13                           NaN                                NaN
# 14                           NaN                                NaN
# 15                          10.0                              12.14
# 16                           NaN                                NaN
# 17                           NaN                                NaN
# 18                          10.0                              11.36
# 19                          10.0                              12.14
# 20                          10.0                              12.53
# 21                           NaN                                NaN
# 22                           NaN                                NaN
# 23                          10.0                              11.36
# 24                          10.0                              11.82
# 25                           NaN                                NaN
# 26                           NaN                                NaN
# 27                          10.0                              12.50
#
#                                                                           \
#
#    NEM True Up Adjustment\n[$] PG&E Electric Delivery Charges\n[$]\n(30)
# 0                         0.00                                     67.83
# 1                         0.00                                     21.75
# 2                          NaN                                       NaN
# 3                          NaN                                       NaN
# 4                         0.00                                     22.53
# 5                          NaN                                       NaN
# 6                          NaN                                       NaN
# 7                         0.00                                     21.36
# 8                          NaN                                       NaN
# 9                          NaN                                       NaN
# 10                        0.00                                     21.75
# 11                         NaN                                       NaN
# 12                         NaN                                       NaN
# 13                         NaN                                       NaN
# 14                         NaN                                       NaN
# 15                        0.00                                     22.14
# 16                         NaN                                       NaN
# 17                         NaN                                       NaN
# 18                        0.00                                     21.36
# 19                        0.00                                     22.14
# 20                        0.00                                     22.53
# 21                         NaN                                       NaN
# 22                         NaN                                       NaN
# 23                        0.00                                     21.36
# 24                        0.00                                     21.82
# 25                         NaN                                       NaN
# 26                         NaN                                       NaN
# 27                      236.95                                    259.45
#
#                                                                    \
#                             Other
#    California Climate Credit\n[$] Total Bill in Mail Monthly  [$]
# 0                             NaN                           67.83
# 1                             NaN                           21.75
# 2                             NaN                             NaN
# 3                             NaN                             NaN
# 4                             NaN                           22.53
# 5                             NaN                             NaN
# 6                             NaN                             NaN
# 7                             NaN                           21.36
# 8                             NaN                             NaN
# 9                             NaN                             NaN
# 10                            NaN                           21.75
# 11                            NaN                             NaN
# 12                            NaN                             NaN
# 13                            NaN                             NaN
# 14                            NaN                             NaN
# 15                         -55.17                          -33.03
# 16                            NaN                             NaN
# 17                            NaN                             NaN
# 18                            NaN                           21.36
# 19                            NaN                           22.14
# 20                            NaN                           22.53
# 21                            NaN                             NaN
# 22                            NaN                             NaN
# 23                            NaN                           89.57
# 24                            NaN                           62.77
# 25                            NaN                             NaN
# 26                            NaN                             NaN
# 27                         -58.23                          207.22
#
#                            303A ADU                                \
#    Meter Import Energy\n(channel 1)
#                     off peak\n[kWh] peak\n[kWh] total\n[kWh]\n(9)
# 0                          298.0000     97.0000             395.0
# 1                          349.0000    102.0000             451.0
# 2                         -842.0000    -64.0000               NaN
# 3                         -220.0000    -24.0000               NaN
# 4                          276.0000     53.0000             329.0
# 5                         -775.0000   -109.0000               NaN
# 6                         -226.0000    -22.0000               NaN
# 7                          409.0000    132.0000             541.0
# 8                          -64.9655     20.6207               NaN
# 9                         -249.0345      5.3793               NaN
# 10                         519.0000    203.0000             726.0
# 11                              NaN         NaN               NaN
# 12                              NaN         NaN               NaN
# 13                        -275.0000     99.0000               NaN
# 14                         -46.0000     33.0000               NaN
# 15                         544.0000    199.0000             743.0
# 16                              NaN         NaN               NaN
# 17                              NaN         NaN               NaN
# 18                         487.0000    168.0000             655.0
# 19                         599.0000    242.0000             841.0
# 20                         693.0000    231.0000             924.0
# 21                              NaN         NaN               NaN
# 22                              NaN         NaN               NaN
# 23                         732.0000      9.0000             741.0
# 24                         592.0000    242.0000             834.0
# 25                              NaN         NaN               NaN
# 26                              NaN         NaN               NaN
# 27                         582.0000    212.0000             794.0
#
#                                                             \
#    Allocated Export Credits
#              off peak\n[kWh] peak\n[kWh] total [kWh]\n(13)
# 0                     -449.0       -58.0            -507.0
# 1                     -707.0       -95.0            -802.0
# 2                      573.0        77.0               NaN
# 3                      131.0        18.0               NaN
# 4                     -546.0       -72.0            -618.0
# 5                      775.0       109.0               NaN
# 6                      226.0        22.0               NaN
# 7                     -723.0      -106.0            -829.0
# 8                        0.0         0.0               NaN
# 9                        0.0         0.0               NaN
# 10                    -953.0      -123.0           -1079.0
# 11                       NaN         NaN               NaN
# 12                       NaN         NaN               NaN
# 13                       0.0         0.0               NaN
# 14                       0.0         0.0               NaN
# 15                    -865.0       -67.0            -932.0
# 16                       NaN         NaN               NaN
# 17                       NaN         NaN               NaN
# 18                    -622.0       -11.0            -633.0
# 19                    -399.0         0.0            -399.0
# 20                     -99.0         0.0             -99.0
# 21                       NaN         NaN               NaN
# 22                       NaN         NaN               NaN
# 23                       0.0       190.0             190.0
# 24                    -456.0        -1.0            -457.0
# 25                       NaN         NaN               NaN
# 26                       NaN         NaN               NaN
# 27                    -670.0       -60.0            -730.0
#
#                                                                           \
#                                Net Energy Usage - After Solar Allocation
#    allocation \n[%]\n(13)/(15)                      off peak [kWh]\n(21)
# 0                     0.508016                                 -151.0000
# 1                     0.500937                                 -358.0000
# 2                          NaN                                 -269.0000
# 3                          NaN                                  -89.0000
# 4                     0.353143                                 -270.0000
# 5                          NaN                                       NaN
# 6                          NaN                                       NaN
# 7                     0.595546                                 -314.0000
# 8                          NaN                                  -64.9655
# 9                          NaN                                 -249.0345
# 10                    0.711741                                 -434.0000
# 11                         NaN                                       NaN
# 12                         NaN                                       NaN
# 13                         NaN                                 -275.0000
# 14                         NaN                                  -46.0000
# 15                    0.721362                                 -321.0000
# 16                         NaN                                       NaN
# 17                         NaN                                       NaN
# 18                    0.639394                                 -135.0000
# 19                    0.659504                                  200.0000
# 20                    0.320388                                  594.0000
# 21                         NaN                                       NaN
# 22                         NaN                                       NaN
# 23                         NaN                                  732.0000
# 24                    0.599738                                  136.0000
# 25                         NaN                                  113.3333
# 26                         NaN                                   22.6667
# 27                    0.619169                                  -88.0000
#
#                                                                     \
#                                       PCE - Peninsula Clean Energy
#    peak [kWh]\n(20) total [kWh]\n(8) PCE - off peak cost [$]\n(24)
# 0           39.0000        -112.0000                    -19.012410
# 1            7.0000        -351.0000                    -45.937300
# 2           13.0000        -256.0000                    -33.869790
# 3           -6.0000         -95.0000                    -12.067510
# 4          -19.0000        -289.0000                    -36.609300
# 5               NaN              NaN                           NaN
# 6               NaN              NaN                           NaN
# 7           26.0000        -288.0000                    -41.637808
# 8           20.6207         -44.3448                     -7.871220
# 9            5.3793        -243.6552                    -33.766588
# 10          80.0000        -354.0000                    -52.583440
# 11              NaN              NaN                           NaN
# 12              NaN              NaN                           NaN
# 13          99.0000        -176.0000                    -33.319000
# 14          33.0000         -13.0000                     -5.410060
# 15         132.0000        -189.0000                    -38.729060
# 16              NaN              NaN                           NaN
# 17              NaN              NaN                           NaN
# 18         157.0000          22.0000                    -15.877350
# 19         242.0000         442.0000                     23.522000
# 20         231.0000         825.0000                     69.860340
# 21              NaN              NaN                           NaN
# 22              NaN              NaN                           NaN
# 23         199.0000         931.0000                     86.090520
# 24         241.0000         377.0000                     15.293427
# 25         200.8333         314.1666                     12.627596
# 26          40.1667          62.8334                      2.665831
# 27         152.0000          64.0000                     -9.800000
#
#                                                              \
#
#    PCE - peak cost \n[$]\n(25) PCE - Energy Cost Total\n[$]
# 0                     5.837910                   -13.174500
# 1                     0.770810                   -45.166490
# 2                     1.945970                          NaN
# 3                    -1.175160                          NaN
# 4                    -3.721340                   -40.330640
# 5                          NaN                          NaN
# 6                          NaN                          NaN
# 7                     5.114684                   -36.523124
# 8                     4.038770                          NaN
# 9                     1.075914                          NaN
# 10                   16.000800                   -36.582640
# 11                         NaN                          NaN
# 12                         NaN                          NaN
# 13                   19.800990                          NaN
# 14                    4.717680                          NaN
# 15                   24.518670                   -14.210390
# 16                         NaN                          NaN
# 17                         NaN                          NaN
# 18                   22.444720                     6.567370
# 19                   34.596320                    58.118320
# 20                   33.023760                   102.884100
# 21                         NaN                          NaN
# 22                         NaN                          NaN
# 23                   28.449040                   114.539560
# 24                   32.941085                    48.234512
# 25                   27.198854                          NaN
# 26                    5.742231                          NaN
# 27                   20.590000                    10.790000
#
#                                           \
#
#    PCE - Net Generation Bonus\n[$]\n(26)
# 0                                  -1.51
# 1                                  -3.64
# 2                                    NaN
# 3                                    NaN
# 4                                  -2.89
# 5                                    NaN
# 6                                    NaN
# 7                                  -3.14
# 8                                    NaN
# 9                                    NaN
# 10                                 -4.34
# 11                                   NaN
# 12                                   NaN
# 13                                   NaN
# 14                                   NaN
# 15                                 -3.21
# 16                                   NaN
# 17                                   NaN
# 18                                 -1.35
# 19                                  0.00
# 20                                  0.00
# 21                                   NaN
# 22                                   NaN
# 23                                  0.00
# 24                                  0.00
# 25                                   NaN
# 26                                   NaN
# 27                                 -0.88
#
#                                                                            \
#
#    Energy Commission Surcharge\n[$]\n(27) PCE - Total Energy Charges\n[$]
# 0                                       0                        -14.6845
# 1                                       0                       -48.80649
# 2                                     NaN                             NaN
# 3                                     NaN                             NaN
# 4                                       0                       -43.22064
# 5                                     NaN                             NaN
# 6                                     NaN                             NaN
# 7                                       0                      -39.663124
# 8                                       `                               `
# 9                                     NaN                             NaN
# 10                                      0                       -40.92264
# 11                                    NaN                             NaN
# 12                                    NaN                             NaN
# 13                                    NaN                             NaN
# 14                                    NaN                             NaN
# 15                                      0                       -17.42039
# 16                                    NaN                             NaN
# 17                                    NaN                             NaN
# 18                                   0.01                         5.22737
# 19                                   0.13                        58.24832
# 20                                   0.25                        103.1341
# 21                                    NaN                             NaN
# 22                                    NaN                             NaN
# 23                                   0.28                       114.81956
# 24                                   0.11                       48.344512
# 25                                    NaN                             NaN
# 26                                    NaN                             NaN
# 27                                   0.02                            9.93
#
#                                                                              \
#
#    PCE NEM Credit\n[$]\n(28) PCE Generation Charges due in Cash \n[$]\n(29)
# 0                      14.68                                              0
# 1                      63.49                                              0
# 2                        NaN                                            NaN
# 3                        NaN                                            NaN
# 4                     106.71                                              0
# 5                        NaN                                            NaN
# 6                        NaN                                            NaN
# 7                     146.37                                              0
# 8                          `                                              `
# 9                        NaN                                            NaN
# 10                    187.29                                              0
# 11                       NaN                                            NaN
# 12                       NaN                                            NaN
# 13                       NaN                                            NaN
# 14                       NaN                                            NaN
# 15                    204.71                                              0
# 16                       NaN                                            NaN
# 17                       NaN                                            NaN
# 18                    199.49                                              0
# 19                    141.24                                              0
# 20                     38.11                                              0
# 21                       NaN                                            NaN
# 22                       NaN                                            NaN
# 23                         0                                          76.71
# 24                         0                                      48.344512
# 25                       NaN                                            NaN
# 26                       NaN                                            NaN
# 27                         0                                           9.93
#
#                                                                             \
#               PG&E - Pacific Gas & Electric                          Other
#    PG&E Electric Delivery Charges [$]\n(42) California Climate Credit\n[$]
# 0                                      7.83                            NaN
# 1                                     11.75                            NaN
# 2                                       NaN                            NaN
# 3                                       NaN                            NaN
# 4                                     12.53                            NaN
# 5                                       NaN                            NaN
# 6                                       NaN                            NaN
# 7                                     11.36                            NaN
# 8                                         `                            NaN
# 9                                       NaN                            NaN
# 10                                    11.75                            NaN
# 11                                      NaN                            NaN
# 12                                      NaN                            NaN
# 13                                      NaN                            NaN
# 14                                      NaN                            NaN
# 15                                    12.14                         -55.17
# 16                                      NaN                            NaN
# 17                                      NaN                            NaN
# 18                                    11.36                            NaN
# 19                                    12.14                            NaN
# 20                                    12.53                            NaN
# 21                                      NaN                            NaN
# 22                                      NaN                            NaN
# 23                                    11.36                            NaN
# 24                                    11.82                            NaN
# 25                                      NaN                            NaN
# 26                                      NaN                            NaN
# 27                                   369.51                         -58.23
#
#
#
#    Total Bill in Mail Monthly\n[$]
# 0                         7.830000
# 1                        11.750000
# 2                              NaN
# 3                              NaN
# 4                        12.530000
# 5                              NaN
# 6                              NaN
# 7                        11.360000
# 8                              NaN
# 9                              NaN
# 10                       11.750000
# 11                             NaN
# 12                             NaN
# 13                        0.000000
# 14                        0.000000
# 15                      -43.030000
# 16                             NaN
# 17                             NaN
# 18                       11.360000
# 19                       12.140000
# 20                       12.530000
# 21                             NaN
# 22                             NaN
# 23                       88.070000
# 24                       60.164512
# 25                             NaN
# 26                             NaN
# 27                      321.210000

# %%
import pandas as pd
from dataclasses import dataclass
from typing import List, Optional
import re
from enum import Enum

class WhichPDF(Enum):
    BILL = 1
    DETAIL_OF_BILL = 2


@dataclass
class EnergyMetric:
    """Represents energy or cost metrics with peak, off-peak, and total values."""
    value: float            # this will be an energy value in kWh, or a cost value in $, or something else like %
    which_pdf: WhichPDF     # tells the person where to find this on the bill
    where_on_pdf: str       # tells the person where to find this on the bill
    unit: str               # the unit of the value, e.g. kWh, $, %
    kevins_number_code: int # a number that Kevin can use to identify this metric by looking at the novermber 2024 sample bill

@dataclass
class EnergyMetrics:
    """Represents energy or cost metrics with peak, off-peak, and total values."""
    peak: EnergyMetric
    off_peak: EnergyMetric
    total: EnergyMetric

@dataclass
class EnergyMetricGroup:
    """Represents the total metric for 1 months of billing, but may have subcomponents where things changes partway through the month."""
    total: EnergyMetrics  # Summed metrics
    subcomponents: List[EnergyMetrics]

@dataclass
class EnergyMonth:
    """Represents a monthly bill for a house with energy and cost metrics."""

    # Meter values
    energy_export_meter_channel_2: EnergyMetricGroup
    energy_import_meter_channel_1: EnergyMetricGroup
    allocated_export_credits: EnergyMetricGroup
    net_energy_usage_after_credits: EnergyMetricGroup

    # PCE values
    pce_energy_cost: EnergyMetricGroup
    pce_net_generation_bonus = EnergyMetric(0, WhichPDF.BILL, "N/A", "$", 0)
    pce_energy_commission_surcharge: EnergyMetric
    pce_total_energy_charges: EnergyMetric
    pce_nem_credit: EnergyMetric
    pce_generation_charges_due_cash: EnergyMetric

    # PG&E
    pge_res_energy_charges: EnergyMetric
    pge_baseline_credit: EnergyMetric
    pge_da_cca_charges: EnergyMetric
    pge_total_energy_charges: EnergyMetric
    pge_nem_billing: EnergyMetric
    pge_minimum_delivery_charge: EnergyMetric
    pge_nem_true_up_adjustment: EnergyMetric
    pge_electric_delivery_charges: EnergyMetric

    # Totals
    california_climate_credit: EnergyMetric
    total_bill_in_mail: EnergyMetric

@dataclass
class House:
    """Represents a house with address and monthly bills."""
    months: dict[str, EnergyMonth]


# instantiate a Month for November 2024
sample = EnergyMonth()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 73
#      69     months: dict[str, EnergyMonth]
#      72 # instantiate a Month for November 2024
# ---> 73 sample = EnergyMonth()
#
# TypeError: EnergyMonth.__init__() missing 19 required positional arguments: 'energy_export_meter_channel_2', 'energy_import_meter_channel_1', 'allocated_export_credits', 'net_energy_usage_after_credits', 'pce_energy_cost', 'pce_energy_commission_surcharge', 'pce_total_energy_charges', 'pce_nem_credit', 'pce_generation_charges_due_cash', 'pge_res_energy_charges', 'pge_baseline_credit', 'pge_da_cca_charges', 'pge_total_energy_charges', 'pge_nem_billing', 'pge_minimum_delivery_charge', 'pge_nem_true_up_adjustment', 'pge_electric_delivery_charges', 'california_climate_credit', and 'total_bill_in_mail'
